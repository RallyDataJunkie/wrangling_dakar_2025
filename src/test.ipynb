# %% [markdown]
# # Dakar 2025
#
# *Notes on scraping Dakar 2025 data.*
#
# Example results page at: https://www.dakar.live.worldrallyraidchampionship.com/en/car/2/latest-ranking
#
# Example standings: https://www.dakar.live.worldrallyraidchampionship.com/en/car/2/standings
#
# From inspection of resources loaded via browser developer tools, we can identify the following data feeds:
#
# - groups feed: https://www.dakar.live.worldrallyraidchampionship.com/api/allGroups-2025
# - example clazz feed: https://www.dakar.live.worldrallyraidchampionship.com/api/allClazz-2025-A
# - example stage feed: https://www.dakar.live.worldrallyraidchampionship.com/api/lastScore-2025-A-1
# - example waypoints feed: https://www.dakar.live.worldrallyraidchampionship.com/api/waypoint-2025-A-1
# - example news feed: https://www.dakar.live.worldrallyraidchampionship.com/api/publication_en-2025-1
# - example withdrawal feed: https://www.dakar.live.worldrallyraidchampionship.com/api/withdrawal-2025-M
#
# API filters are: `-{year}-{category}?-{stage}?`

# %%
CATEGORIES = {"car":"A", "bike":"M"}

# %%
CATEGORY = "car"
STAGE = 2
YEAR = 2025

# %%
import pandas as pd
import requests

# %% [markdown]
# ## Groups
#
# Vehicle groups:

# %%
groups_feed_template = "https://www.dakar.live.worldrallyraidchampionship.com/api/allGroups-{year}"

groups_response = requests.get(groups_feed_template.format(**{"year":YEAR}))

# %%
_groups_df = pd.json_normalize(groups_response.json())
_groups_df["Year"] = YEAR
_groups_df.head(3)
# Out:
#                                   categoryGroupLangs    shortLabel  \
# 0  [{'text': 'M1000 - Bike', 'locale': 'en', 'var...  cat.name.F_M
# 1  [{'text': 'M1000 - Quad', 'variable': 'cat.nam...  cat.name.F_Q
# 2  [{'locale': 'en', 'text': 'M1000 - Car', 'vari...  cat.name.F_A
#
#    promotionalDisplay reference tinyLabel  position label  liveDisplay  \
# 0               False  2025-F-M         M         0     M        False
# 1               False  2025-F-Q         Q         1     Q        False
# 2               False  2025-F-A         A         2     A        False
#
#                    updatedAt  refueling           _bind               _origin  \
# 0  2025-01-05T20:25:31+01:00          0  allGroups-2025  categoryGroup-2025-F
# 1  2025-01-05T20:25:31+01:00          0  allGroups-2025  categoryGroup-2025-F
# 2  2025-01-05T20:25:31+01:00          0  allGroups-2025  categoryGroup-2025-F
#
#                                 _id   _key     _updatedAt  \
# 0  ae6882fe1fcb5dbef0a7e42d7ca802c1  label  1736183714461
# 1  d02ea9bfe0a842c0650bba3c2cf33ecc  label  1736183714461
# 2  d7cb4906cafa111859658683cf820133  label  1736183714461
#
#                                           _parent color  Year  Stage
# 0  category-2025:0a0fb4dfc03bcb6b0e9c940b5a09ae05   NaN  2025      2
# 1  category-2025:0a0fb4dfc03bcb6b0e9c940b5a09ae05   NaN  2025      2
# 2  category-2025:0a0fb4dfc03bcb6b0e9c940b5a09ae05   NaN  2025      2

# %%
_vehicle_labels = (
        groups_df[["categoryGroupLangs"]]
        # categoryGroupLangs is a list of dicts
        # Explode the list over multiple rows, flatten/normalise the dicts,
        # and join the cols back in
        .join(pd.json_normalize(groups_df["categoryGroupLangs"].explode()))
        # Drop the original compound categoryGroupLangs column;
        # the unpacked variable column is a duplicate of the shortLabel
    .drop(["categoryGroupLangs"], axis=1)
    .pivot_table(
    index='variable',
    columns='locale', 
    values='text',
    aggfunc='first'  # Takes first text value if there are duplicates
)
    .reset_index()
    .rename(columns={"variable":"shortLabel"})
    )

_vehicle_labels
# Out:
# locale     shortLabel             ar             en              es  \
# 0        cat.name.F_A    M1000 - Car    M1000 - Car   M1000 - Coche
# 1        cat.name.F_M   M1000 - Bike   M1000 - Bike    M1000 - Moto
# 2        cat.name.F_Q   M1000 - Quad   M1000 - Quad    M1000 - Quad
# 3       cat.name.F_T4            NaN    M1000 - SSV             NaN
# 4       cat.name.F_T5  M1000 - Truck  M1000 - Truck  M1000 - Camión
#
# locale              fr
# 0         M1000 - Auto
# 1         M1000 - Moto
# 2         M1000 - Quad
# 3          M1000 - SSV
# 4       M1000 - Camion

# %%
groups_df = pd.merge(_groups_df, _vehicle_labels, on="shortLabel")
groups_df.drop(["categoryGroupLangs"], axis=1, inplace=True)
groups_df["_label"] = groups_df["en"].str.split("-").str[-1].str.strip()
add_stage_metadata(groups_df)
groups_df
# Out:
#       shortLabel  promotionalDisplay  reference tinyLabel  position label  \
# 0   cat.name.F_M               False   2025-F-M         M         0     M
# 1   cat.name.F_Q               False   2025-F-Q         Q         1     Q
# 2   cat.name.F_A               False   2025-F-A         A         2     A
# 3  cat.name.F_T5               False  2025-F-T5         C         4    T5
# 4  cat.name.F_T4               False  2025-F-T4       SSV         3    T4
#
#    liveDisplay                  updatedAt  refueling           _bind  ...  \
# 0        False  2025-01-05T20:25:31+01:00          0  allGroups-2025  ...
# 1        False  2025-01-05T20:25:31+01:00          0  allGroups-2025  ...
# 2        False  2025-01-05T20:25:31+01:00          0  allGroups-2025  ...
# 3        False  2025-01-05T20:25:31+01:00          0  allGroups-2025  ...
# 4        False  2025-01-05T20:25:31+01:00          0  allGroups-2025  ...
#
#                                 _id   _key     _updatedAt  \
# 0  ae6882fe1fcb5dbef0a7e42d7ca802c1  label  1736183714461
# 1  d02ea9bfe0a842c0650bba3c2cf33ecc  label  1736183714461
# 2  d7cb4906cafa111859658683cf820133  label  1736183714461
# 3  e0dcecc76fec5cd2cd095a09b821242d  label  1736183714461
# 4  f38a8e2eb62f13bc043106815cb187bd  label  1736183714461
#
#                                           _parent color             ar  \
# 0  category-2025:0a0fb4dfc03bcb6b0e9c940b5a09ae05   NaN   M1000 - Bike
# 1  category-2025:0a0fb4dfc03bcb6b0e9c940b5a09ae05   NaN   M1000 - Quad
# 2  category-2025:0a0fb4dfc03bcb6b0e9c940b5a09ae05   NaN    M1000 - Car
# 3  category-2025:0a0fb4dfc03bcb6b0e9c940b5a09ae05   NaN  M1000 - Truck
# 4  category-2025:0a0fb4dfc03bcb6b0e9c940b5a09ae05   NaN            NaN
#
#               en              es              fr _label
# 0   M1000 - Bike    M1000 - Moto    M1000 - Moto   Bike
# 1   M1000 - Quad    M1000 - Quad    M1000 - Quad   Quad
# 2    M1000 - Car   M1000 - Coche    M1000 - Auto    Car
# 3  M1000 - Truck  M1000 - Camión  M1000 - Camion  Truck
# 4    M1000 - SSV             NaN     M1000 - SSV    SSV
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Clazz

# %%
clazz_template = "https://www.dakar.live.worldrallyraidchampionship.com/api/allClazz-{year}-{category}"

clazz_response = requests.get(clazz_template.format(**{"category":CATEGORIES[CATEGORY], "year":YEAR}))

# %%
clazz = pd.json_normalize(clazz_response.json())
clazz["Year"] = YEAR
clazz["Category"] = CATEGORIES[CATEGORY]
clazz
# Out:
#     position label  refueling  promotionalDisplay  \
# 0          1     U          0                True
# 1          0     1          0                True
# 2          3    T4          0               False
# 3          0    NO          0               False
# 4          2  SSV2          0               False
# 5          1  SSV1          0               False
# 6          0   STK          0               False
# 7          1     1          0               False
# 8          2     2          0               False
# 9          3     U          0                True
# 10         4     +          0                True
# 11         1     2          0                True
# 12         2     3          0                True
# 13         0     1          0                True
# 14         1     2          0                True
# 15         2     U          0                True
# 16         0     1          0                True
# 17         4    T3          0                True
# 18         5    T4          0                True
# 19         1    T2          0                True
# 20         0    T1          0                True
# 21         6    T5          0                True
#
#                                    categoryClazzLangs  liveDisplay  \
# 0   [{'variable': 'cat.name.A_T3_U', 'text': 'T3.U...        False
# 1   [{'variable': 'cat.name.A_T3_1', 'text': 'T3.1...        False
# 2   [{'variable': 'cat.name.A_T4_T4', 'locale': 'e...        False
# 3   [{'text': 'T4: Modified Production SSV', 'loca...        False
# 4   [{'variable': 'cat.name.A_T4_SSV2', 'text': 'S...        False
# 5   [{'locale': 'en', 'text': 'SSV1', 'variable': ...        False
# 6   [{'locale': 'en', 'variable': 'cat.name.A_T2_S...        False
# 7   [{'locale': 'en', 'variable': 'cat.name.A_T2_1...        False
# 8   [{'locale': 'en', 'text': 'Stock with expired ...        False
# 9   [{'variable': 'cat.name.A_T1_U', 'locale': 'en...        False
# 10  [{'variable': 'cat.name.A_T1_+', 'text': 'T1+:...        False
# 11  [{'locale': 'en', 'variable': 'cat.name.A_T1_2...        False
# 12  [{'variable': 'cat.name.A_T1_3', 'locale': 'en...        False
# 13  [{'locale': 'en', 'variable': 'cat.name.A_T1_1...        False
# 14  [{'locale': 'en', 'variable': 'cat.name.A_T5_2...        False
# 15  [{'locale': 'en', 'text': 'T5.U: "Ultimate" Pr...        False
# 16  [{'text': 'T5.1: Prototype Cross-Country Truck...        False
# 17                                                NaN         True
# 18                                                NaN         True
# 19                                                NaN         True
# 20                                                NaN         True
# 21                                                NaN         True
#
#             shortLabel                  updatedAt       reference  \
# 0      cat.name.A_T3_U  2025-01-05T20:25:31+01:00     2025-A-T3-U
# 1      cat.name.A_T3_1  2025-01-05T20:25:31+01:00     2025-A-T3-1
# 2     cat.name.A_T4_T4  2025-01-05T20:25:31+01:00    2025-A-T4-T4
# 3     cat.name.A_T4_NO  2025-01-05T20:25:31+01:00    2025-A-T4-NO
# 4   cat.name.A_T4_SSV2  2025-01-05T20:25:31+01:00  2025-A-T4-SSV2
# 5   cat.name.A_T4_SSV1  2025-01-05T20:25:31+01:00  2025-A-T4-SSV1
# 6    cat.name.A_T2_STK  2025-01-05T20:25:31+01:00   2025-A-T2-STK
# 7      cat.name.A_T2_1  2025-01-05T20:25:31+01:00     2025-A-T2-1
# 8      cat.name.A_T2_2  2025-01-05T20:25:31+01:00     2025-A-T2-2
# 9      cat.name.A_T1_U  2025-01-05T20:25:31+01:00     2025-A-T1-U
# 10     cat.name.A_T1_+  2025-01-05T20:25:31+01:00     2025-A-T1-+
# 11     cat.name.A_T1_2  2025-01-05T20:25:31+01:00     2025-A-T1-2
# 12     cat.name.A_T1_3  2025-01-05T20:25:31+01:00     2025-A-T1-3
# 13     cat.name.A_T1_1  2025-01-05T20:25:31+01:00     2025-A-T1-1
# 14     cat.name.A_T5_2  2025-01-05T20:25:31+01:00     2025-A-T5-2
# 15     cat.name.A_T5_U  2025-01-05T20:25:31+01:00     2025-A-T5-U
# 16     cat.name.A_T5_1  2025-01-05T20:25:31+01:00     2025-A-T5-1
# 17       cat.name.A_T3  2025-01-06T12:11:28+01:00       2025-A-T3
# 18       cat.name.A_T4  2025-01-06T12:11:34+01:00       2025-A-T4
# 19       cat.name.A_T2  2025-01-05T20:25:31+01:00       2025-A-T2
# 20       cat.name.A_T1  2025-01-05T20:25:31+01:00       2025-A-T1
# 21       cat.name.A_T5  2025-01-06T12:11:40+01:00       2025-A-T5
#
#                    _bind                  _origin  \
# 0        allClazz-2025-A  categoryClazz-2025-A-T3
# 1        allClazz-2025-A  categoryClazz-2025-A-T3
# 2        allClazz-2025-A  categoryClazz-2025-A-T4
# 3        allClazz-2025-A  categoryClazz-2025-A-T4
# 4        allClazz-2025-A  categoryClazz-2025-A-T4
# 5        allClazz-2025-A  categoryClazz-2025-A-T4
# 6        allClazz-2025-A  categoryClazz-2025-A-T2
# 7        allClazz-2025-A  categoryClazz-2025-A-T2
# 8        allClazz-2025-A  categoryClazz-2025-A-T2
# 9        allClazz-2025-A  categoryClazz-2025-A-T1
# 10       allClazz-2025-A  categoryClazz-2025-A-T1
# 11       allClazz-2025-A  categoryClazz-2025-A-T1
# 12       allClazz-2025-A  categoryClazz-2025-A-T1
# 13       allClazz-2025-A  categoryClazz-2025-A-T1
# 14       allClazz-2025-A  categoryClazz-2025-A-T5
# 15       allClazz-2025-A  categoryClazz-2025-A-T5
# 16       allClazz-2025-A  categoryClazz-2025-A-T5
# 17  categoryGroup-2025-A     categoryGroup-2025-A
# 18  categoryGroup-2025-A     categoryGroup-2025-A
# 19  categoryGroup-2025-A     categoryGroup-2025-A
# 20  categoryGroup-2025-A     categoryGroup-2025-A
# 21  categoryGroup-2025-A     categoryGroup-2025-A
#
#                                  _id   _key     _updatedAt  \
# 0   18af44f476a4dc9363554ccfe1a9b9fe    _id  1736183714844
# 1   a0a6386a4b9a61b73b036a50966345c0    _id  1736183714844
# 2   058d77cc7db191813c30a902a8d5ba7c    _id  1736183714670
# 3   0ec1b5373f8c1fb5ff70ea0590e16c50    _id  1736183714670
# 4   23ae09bc22535129a9af1e6b3071bc2c    _id  1736183714670
# 5   9a68ed3c41c5c7a1642df5d93458baa6    _id  1736183714670
# 6   0f5f4067ac5f62792280af002c46441c    _id  1736183714664
# 7   ba59bf65075fd967e43a906aa8e26487    _id  1736183714664
# 8   eb006e11adce44321f6ca8de47012473    _id  1736183714664
# 9   1501ebcbaf3ad27e72aecfba7faa8037    _id  1736183714852
# 10  96c0869600e0013dbf5f86f60e5c4da4    _id  1736183714852
# 11  f00d7ec8d2d96e9cf11aa515109376cf    _id  1736183714852
# 12  f071b5dbfd586a4ba46100196a98a9c4    _id  1736183714852
# 13  f666973e89db183ecfefc75c3af8ffb1    _id  1736183714852
# 14  ec2f26ebeb14824160c7204618a5780d    _id  1736183714667
# 15  edb3e9e31f0159398924d6f97c275b47    _id  1736183714667
# 16  fa2b8d6b8d84480b3fd11a2fd829b2d6    _id  1736183714667
# 17  15f329900afa29e3e6b099ae681ebe12  label  1736183714456
# 18  423ea731fdcba5cda62c8334985889b0  label  1736183714456
# 19  4dac064bf100bc806b91e7f2e7758297  label  1736183714456
# 20  b49155b3f5670d2a907aa01e319876b8  label  1736183714456
# 21  f1a437ac1135c9d9a5e33f5096f95259  label  1736183714456
#
#                                               _parent  \
# 0   categoryGroup-2025-A:15f329900afa29e3e6b099ae6...
# 1   categoryGroup-2025-A:15f329900afa29e3e6b099ae6...
# 2   categoryGroup-2025-A:423ea731fdcba5cda62c83349...
# 3   categoryGroup-2025-A:423ea731fdcba5cda62c83349...
# 4   categoryGroup-2025-A:423ea731fdcba5cda62c83349...
# 5   categoryGroup-2025-A:423ea731fdcba5cda62c83349...
# 6   categoryGroup-2025-A:4dac064bf100bc806b91e7f2e...
# 7   categoryGroup-2025-A:4dac064bf100bc806b91e7f2e...
# 8   categoryGroup-2025-A:4dac064bf100bc806b91e7f2e...
# 9   categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
# 10  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
# 11  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
# 12  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
# 13  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
# 14  categoryGroup-2025-A:f1a437ac1135c9d9a5e33f509...
# 15  categoryGroup-2025-A:f1a437ac1135c9d9a5e33f509...
# 16  categoryGroup-2025-A:f1a437ac1135c9d9a5e33f509...
# 17     category-2025:63b4f5da4591200d0a4cc239245eb03a
# 18     category-2025:63b4f5da4591200d0a4cc239245eb03a
# 19     category-2025:63b4f5da4591200d0a4cc239245eb03a
# 20     category-2025:63b4f5da4591200d0a4cc239245eb03a
# 21     category-2025:63b4f5da4591200d0a4cc239245eb03a
#
#                                                $group _gets.group  \
# 0   categoryGroup-2025-A:15f329900afa29e3e6b099ae6...      $group
# 1   categoryGroup-2025-A:15f329900afa29e3e6b099ae6...      $group
# 2   categoryGroup-2025-A:423ea731fdcba5cda62c83349...      $group
# 3   categoryGroup-2025-A:423ea731fdcba5cda62c83349...      $group
# 4   categoryGroup-2025-A:423ea731fdcba5cda62c83349...      $group
# 5   categoryGroup-2025-A:423ea731fdcba5cda62c83349...      $group
# 6   categoryGroup-2025-A:4dac064bf100bc806b91e7f2e...      $group
# 7   categoryGroup-2025-A:4dac064bf100bc806b91e7f2e...      $group
# 8   categoryGroup-2025-A:4dac064bf100bc806b91e7f2e...      $group
# 9   categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...      $group
# 10  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...      $group
# 11  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...      $group
# 12  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...      $group
# 13  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...      $group
# 14  categoryGroup-2025-A:f1a437ac1135c9d9a5e33f509...      $group
# 15  categoryGroup-2025-A:f1a437ac1135c9d9a5e33f509...      $group
# 16  categoryGroup-2025-A:f1a437ac1135c9d9a5e33f509...      $group
# 17                                                NaN         NaN
# 18                                                NaN         NaN
# 19                                                NaN         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
#
#                                    categoryGroupLangs tinyLabel    color
# 0                                                 NaN       NaN      NaN
# 1                                                 NaN       NaN      NaN
# 2                                                 NaN       NaN      NaN
# 3                                                 NaN       NaN      NaN
# 4                                                 NaN       NaN      NaN
# 5                                                 NaN       NaN      NaN
# 6                                                 NaN       NaN      NaN
# 7                                                 NaN       NaN      NaN
# 8                                                 NaN       NaN      NaN
# 9                                                 NaN       NaN      NaN
# 10                                                NaN       NaN      NaN
# 11                                                NaN       NaN      NaN
# 12                                                NaN       NaN      NaN
# 13                                                NaN       NaN      NaN
# 14                                                NaN       NaN      NaN
# 15                                                NaN       NaN      NaN
# 16                                                NaN       NaN      NaN
# 17  [{'variable': 'cat.name.A_T3', 'locale': 'en',...       CHG  #E04E39
# 18  [{'locale': 'en', 'variable': 'cat.name.A_T4',...       SSV  #A7C6ED
# 19  [{'locale': 'en', 'variable': 'cat.name.A_T2',...       STK  #C7C9C7
# 20  [{'locale': 'en', 'variable': 'cat.name.A_T1',...       ULT  #EBBC4E
# 21  [{'locale': 'en', 'text': 'Truck', 'variable':...       TRK  #2D2926

# %%
clazz["tinyLabel"].unique()
# Out:
# array([nan, 'CHG', 'SSV', 'STK', 'ULT', 'TRK'], dtype=object)

# %% [markdown]
# ## Waypoints
#
# The waypoints file gives identifiers and kilometer points for each waypoint.

# %%
waypoint_url_template = "https://www.dakar.live.worldrallyraidchampionship.com/api/waypoint-{year}-{category}-{stage}"
waypoint_url_template.format(**{"stage":STAGE, "category":CATEGORIES[CATEGORY], "year":YEAR})
# Out:
# 'https://www.dakar.live.worldrallyraidchampionship.com/api/waypoint-2025-A-2'

# %%
waypoints_response = requests.get(waypoint_url_template.format(**{"stage":1, "category":CATEGORIES[CATEGORY]}))
#waypoints_response.json()

# %%
waypoints = pd.json_normalize(waypoints_response.json()[0]["waypoints"])
waypoints["Year"] = YEAR
waypoints["Stage"] = STAGE
waypoints["category"] = CATEGORIES[CATEGORY]
waypoints
# Out:
#     kilometerPoint  checkpoint   code  kilometerPointDisplay      id  hidden  \
# 0            38.83           1  01207                   39.0  125111   False
# 1            91.04           2  01216                   92.0  125112   False
# 2           121.18           3  01218                  122.0  125113   False
# 3           150.72           4  01220                  151.0  125114   False
# 4           181.18           5  01222                  182.0  125115   False
# 5           212.54           6  01224                  213.0  125116   False
# 6           243.32           7  01227                  244.0  125117   False
# 7           287.02           8  01230                  288.0  125119   False
# 8           329.07           9  01233                  330.0  125120   False
# 9           365.15          10  01237                  366.0  125121    True
# 10          412.95          11  012AS                  413.0  125122   False
# 11            0.00           0  012DS                    0.0  125110   False
# 12             NaN         999  01ASS                    NaN  125123   False
#
#     isCHR  isBRP  isASG  isLBL groups isFirstDss
# 0    True  False  False  False   None        NaN
# 1    True  False  False  False   None        NaN
# 2    True  False  False  False   None        NaN
# 3    True  False  False  False   None        NaN
# 4    True  False  False  False   None        NaN
# 5    True  False  False  False   None        NaN
# 6    True  False  False  False   None        NaN
# 7    True  False  False  False   None        NaN
# 8    True  False  False  False   None        NaN
# 9    True  False  False  False   None        NaN
# 10  False  False  False   True   None        NaN
# 11  False  False  False  False   None       True
# 12  False  False  False   True   None        NaN

# %% [markdown]
# ## Timing and results
#
# Timing and results data for each stage.
#
# We can find the category for a vehicle by taking the `team.clazz` value and cross-referencing it as the `_id` in the corresponding `allClazz-2025-{category}` table, where the `label` gives the category label

# %%
results_feed_template = "https://www.dakar.live.worldrallyraidchampionship.com/api/lastScore-2025-{category}-{stage}"
results_feed_template.format(**{"stage":STAGE,  "category":CATEGORIES[CATEGORY]})
# Out:
# 'https://www.dakar.live.worldrallyraidchampionship.com/api/lastScore-2025-A-2'

# %%
results_response = requests.get(results_feed_template.format(**{"stage":1,"category":CATEGORIES[CATEGORY]}))
#results_response.json()

# %%
results = pd.json_normalize(results_response.json())
results.rename(columns={"_id":"result_id"}, inplace=True)
add_stage_metadata(results)
results
# Out:
#        fsh     wd               _bind     _updatedAt               result_id  \
# 0     True  False  lastScore-2025-A-1  1736187300566  lastScore-2025-A-1-427
# 1    False   True  lastScore-2025-A-1  1736187298618  lastScore-2025-A-1-634
# 2     True  False  lastScore-2025-A-1  1736187300449  lastScore-2025-A-1-330
# 3     True  False  lastScore-2025-A-1  1736187300453  lastScore-2025-A-1-243
# 4     True  False  lastScore-2025-A-1  1736187300444  lastScore-2025-A-1-404
# ..     ...    ...                 ...            ...                     ...
# 196  False  False  lastScore-2025-A-1  1736187300382  lastScore-2025-A-1-212
# 197   True  False  lastScore-2025-A-1  1736187300456  lastScore-2025-A-1-208
# 198  False  False  lastScore-2025-A-1  1736187300505  lastScore-2025-A-1-313
# 199  False  False  lastScore-2025-A-1  1736187300619  lastScore-2025-A-1-628
# 200   True  False  lastScore-2025-A-1  1736187300533  lastScore-2025-A-1-318
#
#      team.bib                        team.clazz team.brand         team.model  \
# 0         427  9a68ed3c41c5c7a1642df5d93458baa6        BRP  CAN-AM MAVERICK R
# 1         634  ec2f26ebeb14824160c7204618a5780d        DAF          FAV 85 MX
# 2         330  a0a6386a4b9a61b73b036a50966345c0     TAURUS             T3 MAX
# 3         243  f00d7ec8d2d96e9cf11aa515109376cf         MD            OPTIMUS
# 4         404  9a68ed3c41c5c7a1642df5d93458baa6        BRP  CAN-AM MAVERICK R
# ..        ...                               ...        ...                ...
# 196       212  96c0869600e0013dbf5f86f60e5c4da4      DACIA          SANDRIDER
# 197       208  96c0869600e0013dbf5f86f60e5c4da4     TOYOTA              HILUX
# 198       313  a0a6386a4b9a61b73b036a50966345c0     TAURUS             T3 MAX
# 199       628  ec2f26ebeb14824160c7204618a5780d      IVECO            TRAKKER
# 200       318  a0a6386a4b9a61b73b036a50966345c0     X-RAID           YXZ1000R
#
#                                       team.competitors  ...  \
# 0    [{'name': 'B. LEPIETRE', 'firstName': 'BENOIT'...  ...
# 1    [{'name': 'J. ESTEVE ORO', 'firstName': 'JORDI...  ...
# 2    [{'name': 'A. ALKUWARI', 'firstName': 'AHMED F...  ...
# 3    [{'name': 'P. THOMASSE', 'firstName': 'PASCAL'...  ...
# 4    [{'name': 'F. LOPEZ CONTARDO', 'firstName': 'F...  ...
# ..                                                 ...  ...
# 196  [{'name': 'C. GUTIERREZ', 'firstName': 'CRISTI...  ...
# 197  [{'name': 'B. VANAGAS', 'firstName': 'BENEDIKT...  ...
# 198  [{'name': 'K. ALJAFLA', 'firstName': 'KHALID',...  ...
# 199  [{'name': 'T. GEUENS', 'firstName': 'TOM', 'la...  ...
# 200  [{'name': 'P. GONÇALVES', 'firstName': 'PEDRO'...  ...
#
#           cs.01ASS.relative  cs.01ASS.bonus  ce.position  \
# 0        [6845000, 6845000]               0   [125, 125]
# 1    [102292000, 102292000]               0   [196, 197]
# 2        [1672000, 1672000]               0     [43, 43]
# 3        [2160000, 2160000]               0     [50, 50]
# 4        [1510000, 1510000]               0     [34, 34]
# ..                      ...             ...          ...
# 196        [133000, 133000]               0       [5, 5]
# 197      [1662000, 1662000]               0     [41, 41]
# 198      [5299000, 5299000]               0   [105, 105]
# 199    [15065000, 15065000]               0   [169, 169]
# 200      [6013000, 6013000]               0   [114, 114]
#
#                 ce.absolute             ce.relative  ce.bonus  \
# 0      [23353000, 23353000]      [6845000, 6845000]         0
# 1    [118800000, 118800000]  [102292000, 102292000]         0
# 2      [18180000, 18180000]      [1672000, 1672000]         0
# 3      [18668000, 18668000]      [2160000, 2160000]         0
# 4      [18018000, 18018000]      [1510000, 1510000]         0
# ..                      ...                     ...       ...
# 196    [16641000, 16641000]        [133000, 133000]         0
# 197    [18170000, 18170000]      [1662000, 1662000]         0
# 198    [21807000, 21807000]      [5299000, 5299000]         0
# 199    [31573000, 31573000]    [15065000, 15065000]         0
# 200    [22521000, 22521000]      [6013000, 6013000]         0
#
#     cg.01ASS.penality cs.01ASS.penality ce.penality team.vehicleImg
# 0                 NaN               NaN         NaN             NaN
# 1          79200000.0        79200000.0  79200000.0             NaN
# 2                 NaN               NaN         NaN             NaN
# 3                 NaN               NaN         NaN             NaN
# 4                 NaN               NaN         NaN             NaN
# ..                ...               ...         ...             ...
# 196               NaN               NaN         NaN             NaN
# 197               NaN               NaN         NaN             NaN
# 198               NaN               NaN         NaN             NaN
# 199               NaN               NaN         NaN             NaN
# 200               NaN               NaN         NaN             NaN
#
# [201 rows x 88 columns]

# %%
# Need a better joining that takes into account year
results = pd.merge(results, clazz[["_id", "label", "shortLabel"]], left_on='team.clazz', right_on='_id')
results
# Out:
#        fsh     wd               _bind     _updatedAt               result_id  \
# 0     True  False  lastScore-2025-A-1  1736187300566  lastScore-2025-A-1-427
# 1    False   True  lastScore-2025-A-1  1736187298618  lastScore-2025-A-1-634
# 2     True  False  lastScore-2025-A-1  1736187300449  lastScore-2025-A-1-330
# 3     True  False  lastScore-2025-A-1  1736187300453  lastScore-2025-A-1-243
# 4     True  False  lastScore-2025-A-1  1736187300444  lastScore-2025-A-1-404
# ..     ...    ...                 ...            ...                     ...
# 196  False  False  lastScore-2025-A-1  1736187300382  lastScore-2025-A-1-212
# 197   True  False  lastScore-2025-A-1  1736187300456  lastScore-2025-A-1-208
# 198  False  False  lastScore-2025-A-1  1736187300505  lastScore-2025-A-1-313
# 199  False  False  lastScore-2025-A-1  1736187300619  lastScore-2025-A-1-628
# 200   True  False  lastScore-2025-A-1  1736187300533  lastScore-2025-A-1-318
#
#      team.bib                        team.clazz team.brand         team.model  \
# 0         427  9a68ed3c41c5c7a1642df5d93458baa6        BRP  CAN-AM MAVERICK R
# 1         634  ec2f26ebeb14824160c7204618a5780d        DAF          FAV 85 MX
# 2         330  a0a6386a4b9a61b73b036a50966345c0     TAURUS             T3 MAX
# 3         243  f00d7ec8d2d96e9cf11aa515109376cf         MD            OPTIMUS
# 4         404  9a68ed3c41c5c7a1642df5d93458baa6        BRP  CAN-AM MAVERICK R
# ..        ...                               ...        ...                ...
# 196       212  96c0869600e0013dbf5f86f60e5c4da4      DACIA          SANDRIDER
# 197       208  96c0869600e0013dbf5f86f60e5c4da4     TOYOTA              HILUX
# 198       313  a0a6386a4b9a61b73b036a50966345c0     TAURUS             T3 MAX
# 199       628  ec2f26ebeb14824160c7204618a5780d      IVECO            TRAKKER
# 200       318  a0a6386a4b9a61b73b036a50966345c0     X-RAID           YXZ1000R
#
#                                       team.competitors  ...  \
# 0    [{'name': 'B. LEPIETRE', 'firstName': 'BENOIT'...  ...
# 1    [{'name': 'J. ESTEVE ORO', 'firstName': 'JORDI...  ...
# 2    [{'name': 'A. ALKUWARI', 'firstName': 'AHMED F...  ...
# 3    [{'name': 'P. THOMASSE', 'firstName': 'PASCAL'...  ...
# 4    [{'name': 'F. LOPEZ CONTARDO', 'firstName': 'F...  ...
# ..                                                 ...  ...
# 196  [{'name': 'C. GUTIERREZ', 'firstName': 'CRISTI...  ...
# 197  [{'name': 'B. VANAGAS', 'firstName': 'BENEDIKT...  ...
# 198  [{'name': 'K. ALJAFLA', 'firstName': 'KHALID',...  ...
# 199  [{'name': 'T. GEUENS', 'firstName': 'TOM', 'la...  ...
# 200  [{'name': 'P. GONÇALVES', 'firstName': 'PEDRO'...  ...
#
#                 ce.absolute             ce.relative  ce.bonus  \
# 0      [23353000, 23353000]      [6845000, 6845000]         0
# 1    [118800000, 118800000]  [102292000, 102292000]         0
# 2      [18180000, 18180000]      [1672000, 1672000]         0
# 3      [18668000, 18668000]      [2160000, 2160000]         0
# 4      [18018000, 18018000]      [1510000, 1510000]         0
# ..                      ...                     ...       ...
# 196    [16641000, 16641000]        [133000, 133000]         0
# 197    [18170000, 18170000]      [1662000, 1662000]         0
# 198    [21807000, 21807000]      [5299000, 5299000]         0
# 199    [31573000, 31573000]    [15065000, 15065000]         0
# 200    [22521000, 22521000]      [6013000, 6013000]         0
#
#      cg.01ASS.penality  cs.01ASS.penality  ce.penality team.vehicleImg  \
# 0                  NaN                NaN          NaN             NaN
# 1           79200000.0         79200000.0   79200000.0             NaN
# 2                  NaN                NaN          NaN             NaN
# 3                  NaN                NaN          NaN             NaN
# 4                  NaN                NaN          NaN             NaN
# ..                 ...                ...          ...             ...
# 196                NaN                NaN          NaN             NaN
# 197                NaN                NaN          NaN             NaN
# 198                NaN                NaN          NaN             NaN
# 199                NaN                NaN          NaN             NaN
# 200                NaN                NaN          NaN             NaN
#
#                                   _id label          shortLabel
# 0    9a68ed3c41c5c7a1642df5d93458baa6  SSV1  cat.name.A_T4_SSV1
# 1    ec2f26ebeb14824160c7204618a5780d     2     cat.name.A_T5_2
# 2    a0a6386a4b9a61b73b036a50966345c0     1     cat.name.A_T3_1
# 3    f00d7ec8d2d96e9cf11aa515109376cf     2     cat.name.A_T1_2
# 4    9a68ed3c41c5c7a1642df5d93458baa6  SSV1  cat.name.A_T4_SSV1
# ..                                ...   ...                 ...
# 196  96c0869600e0013dbf5f86f60e5c4da4     +     cat.name.A_T1_+
# 197  96c0869600e0013dbf5f86f60e5c4da4     +     cat.name.A_T1_+
# 198  a0a6386a4b9a61b73b036a50966345c0     1     cat.name.A_T3_1
# 199  ec2f26ebeb14824160c7204618a5780d     2     cat.name.A_T5_2
# 200  a0a6386a4b9a61b73b036a50966345c0     1     cat.name.A_T3_1
#
# [201 rows x 91 columns]

# %%
results["label"].unique()
# Out:
# array(['SSV1', '2', '1', 'T4', '+', 'U'], dtype=object)

# %%
results["team.competitors"].explode()
# Out:
# 0      {'name': 'B. LEPIETRE', 'firstName': 'BENOIT',...
# 0      {'name': 'R. RELMY-MADINSKA', 'firstName': 'RO...
# 1      {'name': 'J. ESTEVE ORO', 'firstName': 'JORDI'...
# 1      {'name': 'F. PARDO', 'firstName': 'FRANCESC', ...
# 1      {'name': 'J. PUJOL FORNOS', 'firstName': 'JORD...
#                              ...
# 199    {'name': 'T. GEUENS', 'firstName': 'TOM', 'las...
# 199    {'name': 'A. ROBINEAU', 'firstName': 'ANTHONY'...
# 199    {'name': 'S. KOOPMANN', 'firstName': 'SAM', 'l...
# 200    {'name': 'P. GONÇALVES', 'firstName': 'PEDRO',...
# 200    {'name': 'H. MAGALHAES', 'firstName': 'HUGO', ...
# Name: team.competitors, Length: 446, dtype: object

# %%
results.columns
# Out:
# Index(['fsh', 'wd', '_bind', '_updatedAt', 'result_id', 'team.bib',
#        'team.clazz', 'team.brand', 'team.model', 'team.competitors',
#        'team.vehicle', 'team.w2rc', 'dss.position', 'dss.absolute', 'dss.real',
#        'bonif.total', 'bonif.wp', 'cg.01216.position', 'cg.01216.absolute',
#        'cg.01216.relative', 'cg.01218.position', 'cg.01218.absolute',
#        'cg.01218.relative', 'cg.01224.position', 'cg.01224.absolute',
#        'cg.01224.relative', 'cg.01207.position', 'cg.01207.absolute',
#        'cg.01207.relative', 'cg.01233.position', 'cg.01233.absolute',
#        'cg.01233.relative', 'cg.01230.position', 'cg.01230.absolute',
#        'cg.01230.relative', 'cg.01222.position', 'cg.01222.absolute',
#        'cg.01222.relative', 'cg.01220.position', 'cg.01220.absolute',
#        'cg.01220.relative', 'cg.01ASS.position', 'cg.01ASS.absolute',
#        'cg.01ASS.relative', 'cg.01ASS.bonus', 'cg.01ASS.stagePenalty',
#        'cg.01227.position', 'cg.01227.absolute', 'cg.01227.relative',
#        'cs.01207.position', 'cs.01207.absolute', 'cs.01207.relative',
#        'cs.01218.position', 'cs.01218.absolute', 'cs.01218.relative',
#        'cs.01220.position', 'cs.01220.absolute', 'cs.01220.relative',
#        'cs.01216.position', 'cs.01216.absolute', 'cs.01216.relative',
#        'cs.01227.position', 'cs.01227.absolute', 'cs.01227.relative',
#        'cs.01230.position', 'cs.01230.absolute', 'cs.01230.relative',
#        'cs.01222.position', 'cs.01222.absolute', 'cs.01222.relative',
#        'cs.01233.position', 'cs.01233.absolute', 'cs.01233.relative',
#        'cs.01224.position', 'cs.01224.absolute', 'cs.01224.relative',
#        'cs.01ASS.position', 'cs.01ASS.absolute', 'cs.01ASS.relative',
#        'cs.01ASS.bonus', 'ce.position', 'ce.absolute', 'ce.relative',
#        'ce.bonus', 'cg.01ASS.penality', 'cs.01ASS.penality', 'ce.penality',
#        'team.vehicleImg', '_id', 'label', 'shortLabel'],
#       dtype='object')

# %%
results.iloc[0].to_dict()
# Out:
# {'fsh': True,
#  'wd': False,
#  '_bind': 'lastScore-2025-A-1',
#  '_updatedAt': 1736187300566,
#  'result_id': 'lastScore-2025-A-1-427',
#  'team.bib': 427,
#  'team.clazz': '9a68ed3c41c5c7a1642df5d93458baa6',
#  'team.brand': 'BRP',
#  'team.model': 'CAN-AM MAVERICK R',
#  'team.competitors': [{'name': 'B. LEPIETRE',
#    'firstName': 'BENOIT',
#    'lastName': 'LEPIETRE',
#    'role': 'P',
#    'gender': 'm',
#    'nationality': 'fra',
#    'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/427-p/186540/0:0,800:800-0-0-70/d0163',
#    'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/427-p/186540/0:0,800:800-200-0-70/32f43',
#    'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/427-p/191920/0:0,532:690-0-0-70/8be63',
#    'aid': '110add16-df63-4b90-9494-bc3db7d02662'},
#   {'name': 'R. RELMY-MADINSKA',
#    'firstName': 'RODRIGUE',
#    'lastName': 'RELMY-MADINSKA',
#    'role': 'C',
#    'gender': 'm',
#    'nationality': 'fra',
#    'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/427-c/191924/0:0,532:690-0-0-70/acaf9',
#    'aid': '63cb271c-1c74-4f07-82b4-c3df3c425aa7'}],
#  'team.vehicle': 'BTR',
#  'team.w2rc': False,
#  'dss.position': 130,
#  'dss.absolute': 40650000,
#  'dss.real': True,
#  'bonif.total': 0,
#  'bonif.wp': [],
#  'cg.01216.position': [128, 128],
#  'cg.01216.absolute': [4486000, 4486000],
#  'cg.01216.relative': [1159000, 1159000],
#  'cg.01218.position': [127, 127],
#  'cg.01218.absolute': [6139000, 6139000],
#  'cg.01218.relative': [1569000, 1569000],
#  'cg.01224.position': [132, 132],
#  'cg.01224.absolute': [11899000, 11899000],
#  'cg.01224.relative': [3307000, 3307000],
#  'cg.01207.position': [129, 129],
#  'cg.01207.absolute': [1805000, 1805000],
#  'cg.01207.relative': [459000, 459000],
#  'cg.01233.position': [133, 133],
#  'cg.01233.absolute': [19209000, 19209000],
#  'cg.01233.relative': [5981000, 5981000],
#  'cg.01230.position': [136, 136],
#  'cg.01230.absolute': [16833000, 16833000],
#  'cg.01230.relative': [5295000, 5295000],
#  'cg.01222.position': [141, 141],
#  'cg.01222.absolute': [10055000, 10055000],
#  'cg.01222.relative': [2868000, 2868000],
#  'cg.01220.position': [147, 147],
#  'cg.01220.absolute': [8379000, 8379000],
#  'cg.01220.relative': [2489000, 2489000],
#  'cg.01ASS.position': [125, 125],
#  'cg.01ASS.absolute': [23353000, 23353000],
#  'cg.01ASS.relative': [6845000, 6845000],
#  'cg.01ASS.bonus': 0,
#  'cg.01ASS.stagePenalty': 0,
#  'cg.01227.position': [125, 125],
#  'cg.01227.absolute': [14342000, 14342000],
#  'cg.01227.relative': [4099000, 4099000],
#  'cs.01207.position': [129, 129],
#  'cs.01207.absolute': [1805000, 1805000],
#  'cs.01207.relative': [459000, 459000],
#  'cs.01218.position': [127, 127],
#  'cs.01218.absolute': [6139000, 6139000],
#  'cs.01218.relative': [1569000, 1569000],
#  'cs.01220.position': [147, 147],
#  'cs.01220.absolute': [8379000, 8379000],
#  'cs.01220.relative': [2489000, 2489000],
#  'cs.01216.position': [128, 128],
#  'cs.01216.absolute': [4486000, 4486000],
#  'cs.01216.relative': [1159000, 1159000],
#  'cs.01227.position': [125, 125],
#  'cs.01227.absolute': [14342000, 14342000],
#  'cs.01227.relative': [4099000, 4099000],
#  'cs.01230.position': [136, 136],
#  'cs.01230.absolute': [16833000, 16833000],
#  'cs.01230.relative': [5295000, 5295000],
#  'cs.01222.position': [141, 141],
#  'cs.01222.absolute': [10055000, 10055000],
#  'cs.01222.relative': [2868000, 2868000],
#  'cs.01233.position': [133, 133],
#  'cs.01233.absolute': [19209000, 19209000],
#  'cs.01233.relative': [5981000, 5981000],
#  'cs.01224.position': [132, 132],
#  'cs.01224.absolute': [11899000, 11899000],
#  'cs.01224.relative': [3307000, 3307000],
#  'cs.01ASS.position': [125, 125],
#  'cs.01ASS.absolute': [23353000, 23353000],
#  'cs.01ASS.relative': [6845000, 6845000],
#  'cs.01ASS.bonus': 0,
#  'ce.position': [125, 125],
#  'ce.absolute': [23353000, 23353000],
#  'ce.relative': [6845000, 6845000],
#  'ce.bonus': 0,
#  'cg.01ASS.penality': nan,
#  'cs.01ASS.penality': nan,
#  'ce.penality': nan,
#  'team.vehicleImg': nan,
#  '_id': '9a68ed3c41c5c7a1642df5d93458baa6',
#  'label': 'SSV1',
#  'shortLabel': 'cat.name.A_T4_SSV1'}

# %%
# ce - end of stage status
# cg - overall status at waypoint
# cs - stage status at waypoint
# dss - stage start status

# %%
# Claude.ai
import pandas as pd
from typing import Tuple

def normalize_team_competitors(df: pd.DataFrame, year: int=2025) -> Tuple[pd.DataFrame, pd.DataFrame, pd.DataFrame]:
    """
    Transform a DataFrame containing nested competitor lists into two normalized DataFrames
    using vectorized operations.
    
    Args:
        df (pd.DataFrame): Input DataFrame with columns including 'team.bib', 'team.model', 
                          and 'team.competitors' (list of dicts)
    
    Returns:
        Tuple[pd.DataFrame, pd.DataFrame]: (teams_df, competitors_df)
            - teams_df: DataFrame with team information
            - competitors_df: DataFrame with competitor information and team_bib foreign key
            - results_df: DataFrame of results;
    """
    # Create teams DataFrame by dropping the competitors column
    teams_df = df.drop('team.competitors', axis=1)
    
    # Create competitors DataFrame using explode and json_normalize
    competitors_df = (
        df[['team.bib', 'team.competitors']]
        .explode('team.competitors')
        .rename(columns={'team.bib': 'team_bib'})
        .reset_index(drop=True)
    )
    
    # Normalize the dictionary contents and combine with team_bib
    competitors_df = pd.concat([
        competitors_df['team_bib'],
        pd.json_normalize(competitors_df['team.competitors'])
    ], axis=1)

    # Align column names with previous codebase
    competitors_df["Year"] = year
    competitors_df.rename(columns={'team.bib': 'Bib', 'name':'Name'}, inplace=True)

    team_cols =  [c for c in teams_df.columns if c.startswith("team")] + ['label', 'shortLabel']
    teams_df = teams_df[team_cols]
    teams_df.rename(columns={'team.bib': 'Bib'}, inplace=True)

    team_cols.remove("team.bib")
    team_cols.append("team.competitors")
    return teams_df, competitors_df, df.rename(columns={'team.bib': 'Bib'}).drop(team_cols, axis=1)

# %%
teams_df, competitors_df, _results = normalize_team_competitors(results)

# %%
_results.columns, display(_results.head())
# Out:
#      fsh     wd               _bind     _updatedAt               result_id  \
# 0   True  False  lastScore-2025-A-1  1736187300566  lastScore-2025-A-1-427
# 1  False   True  lastScore-2025-A-1  1736187298618  lastScore-2025-A-1-634
# 2   True  False  lastScore-2025-A-1  1736187300449  lastScore-2025-A-1-330
# 3   True  False  lastScore-2025-A-1  1736187300453  lastScore-2025-A-1-243
# 4   True  False  lastScore-2025-A-1  1736187300444  lastScore-2025-A-1-404
#
#    Bib  dss.position  dss.absolute  dss.real  bonif.total  ...  \
# 0  427           130      40650000      True            0  ...
# 1  634           171      41910000      True            0  ...
# 2  330            55      38370000      True            0  ...
# 3  243            67      38730000      True            0  ...
# 4  404            72      38880000      True            0  ...
#
#         cs.01ASS.relative cs.01ASS.bonus ce.position             ce.absolute  \
# 0      [6845000, 6845000]              0  [125, 125]    [23353000, 23353000]
# 1  [102292000, 102292000]              0  [196, 197]  [118800000, 118800000]
# 2      [1672000, 1672000]              0    [43, 43]    [18180000, 18180000]
# 3      [2160000, 2160000]              0    [50, 50]    [18668000, 18668000]
# 4      [1510000, 1510000]              0    [34, 34]    [18018000, 18018000]
#
#               ce.relative ce.bonus cg.01ASS.penality cs.01ASS.penality  \
# 0      [6845000, 6845000]        0               NaN               NaN
# 1  [102292000, 102292000]        0        79200000.0        79200000.0
# 2      [1672000, 1672000]        0               NaN               NaN
# 3      [2160000, 2160000]        0               NaN               NaN
# 4      [1510000, 1510000]        0               NaN               NaN
#
#   ce.penality                               _id
# 0         NaN  9a68ed3c41c5c7a1642df5d93458baa6
# 1  79200000.0  ec2f26ebeb14824160c7204618a5780d
# 2         NaN  a0a6386a4b9a61b73b036a50966345c0
# 3         NaN  f00d7ec8d2d96e9cf11aa515109376cf
# 4         NaN  9a68ed3c41c5c7a1642df5d93458baa6
#
# [5 rows x 82 columns]
# (Index(['fsh', 'wd', '_bind', '_updatedAt', 'result_id', 'Bib', 'dss.position',
#         'dss.absolute', 'dss.real', 'bonif.total', 'bonif.wp',
#         'cg.01216.position', 'cg.01216.absolute', 'cg.01216.relative',
#         'cg.01218.position', 'cg.01218.absolute', 'cg.01218.relative',
#         'cg.01224.position', 'cg.01224.absolute', 'cg.01224.relative',
#         'cg.01207.position', 'cg.01207.absolute', 'cg.01207.relative',
#         'cg.01233.position', 'cg.01233.absolute', 'cg.01233.relative',
#         'cg.01230.position', 'cg.01230.absolute', 'cg.01230.relative',
#         'cg.01222.position', 'cg.01222.absolute', 'cg.01222.relative',
#         'cg.01220.position', 'cg.01220.absolute', 'cg.01220.relative',
#         'cg.01ASS.position', 'cg.01ASS.absolute', 'cg.01ASS.relative',
#         'cg.01ASS.bonus', 'cg.01ASS.stagePenalty', 'cg.01227.position',
#         'cg.01227.absolute', 'cg.01227.relative', 'cs.01207.position',
#         'cs.01207.absolute', 'cs.01207.relative', 'cs.01218.position',
#         'cs.01218.absolute', 'cs.01218.relative', 'cs.01220.position',
#         'cs.01220.absolute', 'cs.01220.relative', 'cs.01216.position',
#         'cs.01216.absolute', 'cs.01216.relative', 'cs.01227.position',
#         'cs.01227.absolute', 'cs.01227.relative', 'cs.01230.position',
#         'cs.01230.absolute', 'cs.01230.relative', 'cs.01222.position',
#         'cs.01222.absolute', 'cs.01222.relative', 'cs.01233.position',
#         'cs.01233.absolute', 'cs.01233.relative', 'cs.01224.position',
#         'cs.01224.absolute', 'cs.01224.relative', 'cs.01ASS.position',
#         'cs.01ASS.absolute', 'cs.01ASS.relative', 'cs.01ASS.bonus',
#         'ce.position', 'ce.absolute', 'ce.relative', 'ce.bonus',
#         'cg.01ASS.penality', 'cs.01ASS.penality', 'ce.penality', '_id'],
#        dtype='object'),
#  None)

# %%
teams_df.head()
# Out:
#    Bib                        team.clazz team.brand         team.model  \
# 0  427  9a68ed3c41c5c7a1642df5d93458baa6        BRP  CAN-AM MAVERICK R
# 1  634  ec2f26ebeb14824160c7204618a5780d        DAF          FAV 85 MX
# 2  330  a0a6386a4b9a61b73b036a50966345c0     TAURUS             T3 MAX
# 3  243  f00d7ec8d2d96e9cf11aa515109376cf         MD            OPTIMUS
# 4  404  9a68ed3c41c5c7a1642df5d93458baa6        BRP  CAN-AM MAVERICK R
#
#           team.vehicle  team.w2rc team.vehicleImg label          shortLabel
# 0                  BTR      False             NaN  SSV1  cat.name.A_T4_SSV1
# 1           TIBAU TEAM      False             NaN     2     cat.name.A_T5_2
# 2        NASSER RACING      False             NaN     1     cat.name.A_T3_1
# 3      MD RALLYE SPORT      False             NaN     2     cat.name.A_T1_2
# 4  CAN-AM FACTORY TEAM      False             NaN  SSV1  cat.name.A_T4_SSV1

# %%
competitors_df
# Out:
#      team_bib               Name firstName        lastName role gender  \
# 0         427        B. LEPIETRE    BENOIT        LEPIETRE    P      m
# 1         427  R. RELMY-MADINSKA  RODRIGUE  RELMY-MADINSKA    C      m
# 2         634      J. ESTEVE ORO     JORDI      ESTEVE ORO    P      m
# 3         634           F. PARDO  FRANCESC           PARDO    C      m
# 4         634    J. PUJOL FORNOS     JORDI    PUJOL FORNOS    M      m
# ..        ...                ...       ...             ...  ...    ...
# 441       628          T. GEUENS       TOM          GEUENS    P      m
# 442       628        A. ROBINEAU   ANTHONY        ROBINEAU    C      m
# 443       628        S. KOOPMANN       SAM        KOOPMANN    M      m
# 444       318       P. GONÇALVES     PEDRO       GONÇALVES    P      m
# 445       318       H. MAGALHAES      HUGO       MAGALHAES    C      m
#
#     nationality                                             profil  \
# 0           fra  https://img.aso.fr/core_app/img-motorSports-da...
# 1           fra                                                NaN
# 2           esp  https://img.aso.fr/core_app/img-motorSports-da...
# 3           esp  https://img.aso.fr/core_app/img-motorSports-da...
# 4           esp  https://img.aso.fr/core_app/img-motorSports-da...
# ..          ...                                                ...
# 441         bel  https://img.aso.fr/core_app/img-motorSports-da...
# 442         fra  https://img.aso.fr/core_app/img-motorSports-da...
# 443         fra  https://img.aso.fr/core_app/img-motorSports-da...
# 444         prt  https://img.aso.fr/core_app/img-motorSports-da...
# 445         prt  https://img.aso.fr/core_app/img-motorSports-da...
#
#                                              profil_sm  \
# 0    https://img.aso.fr/core_app/img-motorSports-da...
# 1                                                  NaN
# 2    https://img.aso.fr/core_app/img-motorSports-da...
# 3    https://img.aso.fr/core_app/img-motorSports-da...
# 4    https://img.aso.fr/core_app/img-motorSports-da...
# ..                                                 ...
# 441  https://img.aso.fr/core_app/img-motorSports-da...
# 442  https://img.aso.fr/core_app/img-motorSports-da...
# 443  https://img.aso.fr/core_app/img-motorSports-da...
# 444  https://img.aso.fr/core_app/img-motorSports-da...
# 445  https://img.aso.fr/core_app/img-motorSports-da...
#
#                                                 podium  \
# 0    https://img.aso.fr/core_app/img-motorSports-da...
# 1    https://img.aso.fr/core_app/img-motorSports-da...
# 2    https://img.aso.fr/core_app/img-motorSports-da...
# 3    https://img.aso.fr/core_app/img-motorSports-da...
# 4    https://img.aso.fr/core_app/img-motorSports-da...
# ..                                                 ...
# 441  https://img.aso.fr/core_app/img-motorSports-da...
# 442  https://img.aso.fr/core_app/img-motorSports-da...
# 443  https://img.aso.fr/core_app/img-motorSports-da...
# 444  https://img.aso.fr/core_app/img-motorSports-da...
# 445  https://img.aso.fr/core_app/img-motorSports-da...
#
#                                       aid  Year
# 0    110add16-df63-4b90-9494-bc3db7d02662  2025
# 1    63cb271c-1c74-4f07-82b4-c3df3c425aa7  2025
# 2    36106f23-d545-47b9-8565-983cce7550d3  2025
# 3    43c1ce16-ccee-4ac2-ae16-b89e82a43183  2025
# 4    7700b503-68b6-4aca-a63a-96047071c2e9  2025
# ..                                    ...   ...
# 441  30d267bb-e624-4ac2-9886-e6e63709c0e3  2025
# 442  bd2e9505-c05c-408e-8f76-620b2e61607a  2025
# 443  80df715b-dad9-44f8-b4a4-90631d782835  2025
# 444  4cd2f99a-77e1-46a8-853b-15ac02f2d196  2025
# 445  6f8e4915-b205-4940-9d87-992e96993fb6  2025
#
# [446 rows x 12 columns]

# %%
id_column="_id"
point_cols = [col for col in _results.columns if col.startswith(('cg', 'cs'))]
# Melt only the point-specific columns
melted = _results[[id_column, "Bib", *point_cols]].melt(id_vars=[id_column, "Bib"]).dropna()
melted = melted[melted['variable'].str.contains('position|absolute|relative')]
melted["type"] = melted["variable"].str.split('.').str[0]
melted["waypoint"] = melted["variable"].str.extract(r'\.([^\.]+)\.')
melted["metric"] = melted["variable"].str.split('.').str[-1]

melted[['value_0', 'value_1']] = pd.DataFrame(
        melted['value'].tolist(), 
        index=melted.index
    )
# TO DO - drop: variable, value, _id
# TO DO - have a backup table of _id and Bib
# TO DO - add: Year, Stage
melted
# Out:
#                                     _id  Bib           variable  \
# 0      9a68ed3c41c5c7a1642df5d93458baa6  427  cg.01216.position
# 1      ec2f26ebeb14824160c7204618a5780d  634  cg.01216.position
# 2      a0a6386a4b9a61b73b036a50966345c0  330  cg.01216.position
# 3      f00d7ec8d2d96e9cf11aa515109376cf  243  cg.01216.position
# 4      9a68ed3c41c5c7a1642df5d93458baa6  404  cg.01216.position
# ...                                 ...  ...                ...
# 12457  96c0869600e0013dbf5f86f60e5c4da4  212  cs.01ASS.relative
# 12458  96c0869600e0013dbf5f86f60e5c4da4  208  cs.01ASS.relative
# 12459  a0a6386a4b9a61b73b036a50966345c0  313  cs.01ASS.relative
# 12460  ec2f26ebeb14824160c7204618a5780d  628  cs.01ASS.relative
# 12461  a0a6386a4b9a61b73b036a50966345c0  318  cs.01ASS.relative
#
#                       value type waypoint    metric   value_0   value_1
# 0                [128, 128]   cg    01216  position       128       128
# 1                [194, 194]   cg    01216  position       194       194
# 2                  [53, 53]   cg    01216  position        53        53
# 3                  [60, 60]   cg    01216  position        60        60
# 4                  [65, 65]   cg    01216  position        65        65
# ...                     ...  ...      ...       ...       ...       ...
# 12457      [133000, 133000]   cs    01ASS  relative    133000    133000
# 12458    [1662000, 1662000]   cs    01ASS  relative   1662000   1662000
# 12459    [5299000, 5299000]   cs    01ASS  relative   5299000   5299000
# 12460  [15065000, 15065000]   cs    01ASS  relative  15065000  15065000
# 12461    [6013000, 6013000]   cs    01ASS  relative   6013000   6013000
#
# [11706 rows x 9 columns]

# %%
melted["type"].unique()
# Out:
# array(['cg', 'cs', 'ce'], dtype=object)

# %%
xx = (melted[["_id", "Bib",  "waypoint", "metric",	"value_0","value_1"]].pivot(    index=[id_column, "Bib",'waypoint'],   columns='metric',     values=['value_0', 'value_1'] ) )
xx
# Out:
#                                                 value_0                     \
# metric                                         absolute position  relative
# _id                              Bib waypoint
# 058d77cc7db191813c30a902a8d5ba7c 400 01207      1532000       46    186000
#                                      01216      3760000       49    433000
#                                      01218      5124000       46    554000
#                                      01220      6461000       44    571000
#                                      01222      7846000       36    659000
# ...                                                 ...      ...       ...
# fa2b8d6b8d84480b3fd11a2fd829b2d6 633 01224     14800000      169   6208000
#                                      01227     17597000      165   7354000
#                                      01230     19989000      163   8451000
#                                      01233     23121000      171   9893000
#                                      01ASS     28683000      158  12175000
#
#                                                 value_1
# metric                                         absolute position  relative
# _id                              Bib waypoint
# 058d77cc7db191813c30a902a8d5ba7c 400 01207      1532000       46    186000
#                                      01216      3760000       49    433000
#                                      01218      5124000       46    554000
#                                      01220      6461000       44    571000
#                                      01222      7846000       36    659000
# ...                                                 ...      ...       ...
# fa2b8d6b8d84480b3fd11a2fd829b2d6 633 01224     14800000      169   6208000
#                                      01227     17597000      165   7354000
#                                      01230     19989000      163   8451000
#                                      01233     23121000      171   9893000
#                                      01ASS     28683000      158  12175000
#
# [1951 rows x 6 columns]

# %%
xx["value_0"]
# Out:
# metric                          absolute  position  relative
# _id                   waypoint
# lastScore-2025-M-1-1  01207      2485000         3     16000
#                       01216      4564000         3     33000
#                       01218      5911000         1         0
#                       01220      7272000         3     60000
#                       01222      8590000         2     14000
# ...                                  ...       ...       ...
# lastScore-2025-M-1-99 01224     12284000        46   2268000
#                       01227     14358000        44   2696000
#                       01230     15892000        46   2955000
#                       01233     18013000        45   3268000
#                       01ASS     22219000        49   4321000
#
# [1304 rows x 3 columns]

# %% [markdown]
# ## Original Database

# %%
import sqlite3
from sqlite_utils import Database

dbname = 'dakar_2020.db'

conn = sqlite3.connect(dbname)
db = Database(conn)

# %%
db.tables
# Out:
# [<Table teams (Year, Bib, Team)>,
#  <Table crew (Year, Bib, Num, Name, Country)>,
#  <Table vehicles (Year, Bib, VehicleType, Brand)>,
#  <Table stagestats (Year, Stage, Start, Liaison, Special, AtStart, Left, Arrived, LatestWP, LeaderLatestWP, NumLatestWP, BibLatestWP, NameLatestWP, Vehicle, StageDist)>,
#  <Table ranking (Year, Stage, Type, Pos, Bib, VehicleType, Crew, Brand, Time_raw, TimeInS, Gap_raw, GapInS, Penalty_raw, PenaltyInS)>,
#  <Table waypoints (Year, Stage, Bib, Pos, Waypoint, WaypointOrder, WaypointRank, WaypointPos, Time_raw, TimeInS, Gap_raw, GapInS, WaypointDist, VehicleType, splitS)>]

# %%
 pd.DataFrame(db["teams"].rows).head()
# Out:
#    Year  Bib                                      Team
# 0  2020    1                 RED BULL KTM FACTORY TEAM
# 1  2020    2                 RED BULL KTM FACTORY TEAM
# 2  2020    3                 RED BULL KTM FACTORY TEAM
# 3  2020    4          MONSTER ENERGY YAMAHA RALLY TEAM
# 4  2020    5  ROCKSTAR ENERGY HUSQVARNA FACTORY RACING

# %%
 pd.DataFrame(db["crew"].rows).head()
# Out:
#    Year  Bib  Num            Name         Country
# 0  2020    1    0        T. PRICE       Australia
# 1  2020    2    0      M. WALKNER         Austria
# 2  2020    3    0   S. SUNDERLAND  United Kingdom
# 3  2020    4    0  A. VAN BEVEREN          France
# 4  2020    5    0  P. QUINTANILLA           Chile

# %%
 pd.DataFrame(db["stagestats"].rows).head()
# Out:
#    Year  Stage  Start Liaison Special  AtStart  Left  Arrived LatestWP  \
# 0  2020      1  07:20   433km   319km      144   144      140      ass
# 1  2020      1  08:34   433km   319km       23    23       22      ass
# 2  2020      1  09:20   433km   319km       83    82       81      ass
# 3  2020      1  10:49   433km   319km       46    46       45      ass
# 4  2020      1  11:50   433km   319km       46    41       40      ass
#
#   LeaderLatestWP NumLatestWP  BibLatestWP NameLatestWP Vehicle  StageDist
# 0      001 PRICE         140            1        PRICE    Moto        319
# 1     250 CASALE          22          250       CASALE    Quad        319
# 2       319 ZALA          81          319         ZALA     Car        319
# 3    419 DOMZALA          45          419      DOMZALA     SSV        319
# 4   516 SHIBALOV          40          516     SHIBALOV   Truck        319

# %%
 pd.DataFrame(db["ranking"].rows).head()
# Out:
#    Year  Stage   Type  Pos  Bib VehicleType  \
# 0  2020      1  stage    1  319         car
# 1  2020      1  stage    2  302         car
# 2  2020      1  stage    3  305         car
# 3  2020      1  stage    4  300         car
# 4  2020      1  stage    5  307         car
#
#                                               Crew   Brand  Time_raw  TimeInS  \
# 0                  V. ZALA S. JURGELENAS AGRORODEO    MINI  03:19:04  11944.0
# 1  S. PETERHANSEL P. FIUZA BAHRAIN JCW X-RAID TEAM    MINI  03:21:18  12078.0
# 2         C. SAINZ L. CRUZ BAHRAIN JCW X-RAID TEAM    MINI  03:21:54  12114.0
# 3      N. AL-ATTIYAH M. BAUMEL TOYOTA GAZOO RACING  TOYOTA  03:24:37  12277.0
# 4     B. TEN BRINKE T. COLSOUL TOYOTA GAZOO RACING  TOYOTA  03:25:34  12334.0
#
#    Gap_raw  GapInS Penalty_raw  PenaltyInS
# 0  0:00:00     0.0    00:00:00         0.0
# 1  0:02:14   134.0    00:00:00         0.0
# 2  0:02:50   170.0    00:00:00         0.0
# 3  0:05:33   333.0    00:00:00         0.0
# 4  0:06:30   390.0    00:00:00         0.0

# %%
 pd.DataFrame(db["waypoints"].rows).head()
# Out:
#    Year  Stage  Bib  Pos Waypoint  WaypointOrder  WaypointRank  WaypointPos  \
# 0  2020      1  319  1.0  01_km47              1          11.0           10
# 1  2020      1  302  2.0  01_km47              1           7.0            7
# 2  2020      1  305  3.0  01_km47              1           4.0            4
# 3  2020      1  300  4.0  01_km47              1           1.0            1
# 4  2020      1  307  5.0  01_km47              1           8.0            8
#
#    Time_raw  TimeInS   Gap_raw  GapInS  WaypointDist VehicleType  splitS
# 0  00:36:18   2178.0  00:02:18   138.0            47         car  2178.0
# 1  00:35:30   2130.0  00:01:30    90.0            47         car  2130.0
# 2  00:34:43   2083.0  00:00:43    43.0            47         car  2083.0
# 3  00:34:00   2040.0  00:00:00     0.0            47         car  2040.0
# 4  00:36:01   2161.0  00:02:01   121.0            47         car  2161.0

# %%
from Dakar_Rally_2021 import dbfy

conn25 = sqlite3.connect("test2025.db")

c25 = conn25.cursor()

setup25_sql= 'dakar25.sql'

with open(setup25_sql,'r') as f:
     txt = f.read()
     c25.executescript(txt)

db25 =  Database(conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[35], line 11
#       9 with open(setup25_sql,'r') as f:
#      10      txt = f.read()
# ---> 11      c25.executescript(txt)
#      13 db25 =  Database(conn)
#
# OperationalError: expressions prohibited in PRIMARY KEY and UNIQUE constraints

# %%
competitors_df.columns

# %%
competitors_df.head()
