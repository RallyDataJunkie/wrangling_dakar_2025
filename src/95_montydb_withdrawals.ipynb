# %% [markdown]
# # MontyDB demos

# %%
# Load in the required packages
import pandas as pd
from jupyterlite_simple_cors_proxy import furl, xurl

# Generate the API URL pattern
dakar_api_template = "https://www.dakar.live.worldrallyraidchampionship.com/api/{path}"

# Define the year
YEAR = 2025
# Define the category
CATEGORY = "A"

# Define the API path to the withdrawal resource
# Use a Python f-string to instantiate variable values directly
withdrawal_path = f"withdrawal-{YEAR}-{CATEGORY}"

# Define the URL
withdrawal_url = dakar_api_template.format(path=withdrawal_path)
withdrawal_url
# Out:
# 'https://www.dakar.live.worldrallyraidchampionship.com/api/withdrawal-2025-A'

# %%
import requests
w_json = requests.get(xurl(withdrawal_url)).json()

# %%
from montydb import MontyClient

db = MontyClient(":memory:").db
col = db.test
col.insert_many( w_json )
# Out:
# InsertManyResult(
#   'withdrawal-2025-A-9',
#   'withdrawal-2025-A-6',
#   'withdrawal-2025-A-2',
#   'withdrawal-2025-A-3',
#   'withdrawal-2025-A-4',
#   'withdrawal-2025-A-8',
#   'withdrawal-2025-A-5',
#   'withdrawal-2025-A-7',
#   'withdrawal-2025-A-11',
#   'withdrawal-2025-A-12',
#   'withdrawal-2025-A-10'
# )

# %%
cur = col.find({"stage":5}, {"_id":0,"list":1, "stage":1})
"""
"list", {
    "reason": "2",
    "team.w2rc": True
}
"""
next(cur)
# Out:
# {'list': [{'bib': 208,
#    'reason': '1',
#    'team': {'bib': 208,
#     'brand': 'TOYOTA',
#     'model': 'HILUX',
#     'vehicle': 'GURTAM TOYOTA GAZOO RACING BALTICS',
#     'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/208/194454/0:0,600:500-0-0-70/1280a',
#     'clazz': '96c0869600e0013dbf5f86f60e5c4da4',
#     'w2rc': False,
#     'competitors': [{'name': 'B. VANAGAS',
#       'firstName': 'BENEDIKTAS',
#       'lastName': 'VANAGAS',
#       'role': 'P',
#       'gender': 'm',
#       'nationality': 'ltu',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/208-p/195817/0:0,800:800-0-0-70/07130',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/208-p/195817/0:0,800:800-200-0-70/aa4f1',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/208-p/192806/0:0,532:690-0-0-70/5ffab',
#       'aid': '77735d6e-4d5a-421d-8a32-0b3f21629f04'},
#      {'name': 'S. GOSPODARCZYK',
#       'firstName': 'SZYMON',
#       'lastName': 'GOSPODARCZYK',
#       'role': 'C',
#       'gender': 'm',
#       'nationality': 'pol',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/208-c/196145/0:0,800:800-0-0-70/39923',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/208-c/196145/0:0,800:800-200-0-70/18f3a',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/208-c/191149/0:0,532:690-0-0-70/f75e8',
#       'aid': 'ff266183-f351-48e2-bac0-d6736f542370'}]}},
#   {'bib': 247,
#    'reason': '1',
#    'team': {'bib': 247,
#     'brand': 'RED-LINED',
#     'model': 'REVO T1+',
#     'vehicle': 'HANWEI MOTORSPORT TEAM',
#     'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/247/193949/0:0,600:500-0-0-70/4307c',
#     'clazz': '96c0869600e0013dbf5f86f60e5c4da4',
#     'w2rc': False,
#     'competitors': [{'name': 'P. TIAN',
#       'firstName': 'PO',
#       'lastName': 'TIAN',
#       'role': 'P',
#       'gender': 'm',
#       'nationality': 'chn',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/247-p/195755/0:0,800:800-0-0-70/af616',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/247-p/195755/0:0,800:800-200-0-70/b26a7',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/247-p/192778/0:0,532:690-0-0-70/e417a',
#       'aid': '21cd00ff-265f-461d-9966-2633c0a9717e'},
#      {'name': 'H. GUO',
#       'firstName': 'HANGTING',
#       'lastName': 'GUO',
#       'role': 'C',
#       'gender': 'm',
#       'nationality': 'chn',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/247-c/196096/0:0,800:800-0-0-70/b7022',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/247-c/196096/0:0,800:800-200-0-70/ee92e',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/247-c/192643/0:0,532:690-0-0-70/b10bf',
#       'aid': 'c12c158d-b0c6-4ad1-a6dc-33a9acebb46f'}]}},
#   {'bib': 309,
#    'reason': '1',
#    'team': {'bib': 309,
#     'brand': 'TAURUS',
#     'model': 'T3 MAX',
#     'vehicle': 'NASSER RACING',
#     'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309/194406/0:0,600:500-0-0-70/b16a2',
#     'clazz': 'a0a6386a4b9a61b73b036a50966345c0',
#     'w2rc': True,
#     'competitors': [{'name': 'E. PONS',
#       'firstName': 'EDUARD',
#       'lastName': 'PONS',
#       'role': 'P',
#       'gender': 'm',
#       'nationality': 'esp',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-p/195921/0:0,800:800-0-0-70/760ed',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-p/195921/0:0,800:800-200-0-70/d21d9',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-p/192526/0:0,532:690-0-0-70/b071c',
#       'aid': 'a3da2c1f-22cb-4ec6-91cd-8219d543c478'},
#      {'name': 'J. BETRIU',
#       'firstName': 'JAUME',
#       'lastName': 'BETRIU',
#       'role': 'C',
#       'gender': 'm',
#       'nationality': 'esp',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-c/196102/0:0,800:800-0-0-70/bb562',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-c/196102/0:0,800:800-200-0-70/0506a',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-c/192823/0:0,532:690-0-0-70/ec2a7',
#       'aid': '6e68a900-0a4a-41d7-b852-cbc75e4ff2a4'}]}},
#   {'bib': 314,
#    'reason': '1',
#    'team': {'bib': 314,
#     'brand': 'ORYX',
#     'model': 'T3',
#     'vehicle': 'FOJ MOTORSPORT',
#     'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/314/194155/0:0,600:500-0-0-70/c2863',
#     'clazz': 'a0a6386a4b9a61b73b036a50966345c0',
#     'w2rc': False,
#     'competitors': [{'name': 'X. FOJ',
#       'firstName': 'XAVIER',
#       'lastName': 'FOJ',
#       'role': 'P',
#       'gender': 'm',
#       'nationality': 'esp',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/314-p/195696/0:0,800:800-0-0-70/363db',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/314-p/195696/0:0,800:800-200-0-70/9167a',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/314-p/193002/0:0,532:690-0-0-70/b2759',
#       'aid': 'fe69eeef-bb61-445b-bd6f-a7d352ff2525'},
#      {'name': 'F. JATON',
#       'firstName': 'FACUNDO',
#       'lastName': 'JATON',
#       'role': 'C',
#       'gender': 'm',
#       'nationality': 'arg',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/314-c/196090/0:0,800:800-0-0-70/bd58c',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/314-c/196090/0:0,800:800-200-0-70/1ae87',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/314-c/191128/0:0,532:690-0-0-70/c3379',
#       'aid': 'eec7dd7a-7c04-4340-a515-7c7996fb7bfa'}]}},
#   {'bib': 352,
#    'reason': '1',
#    'team': {'bib': 352,
#     'brand': 'BRP',
#     'model': 'CAN-AM MAVERICK X3',
#     'vehicle': 'BUJARKAY-MAKARTHY RACING',
#     'clazz': 'a0a6386a4b9a61b73b036a50966345c0',
#     'w2rc': False,
#     'competitors': [{'name': 'O. OLIVAS',
#       'firstName': 'OSCAR',
#       'lastName': 'OLIVAS',
#       'role': 'P',
#       'gender': 'm',
#       'nationality': 'esp',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/a1974/196341/0:0,800:800-0-0-70/193d3',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/a1974/196341/0:0,800:800-200-0-70/3ca0e',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/62dc2/196342/0:0,532:690-0-0-70/48962',
#       'aid': '74362c56-c806-42e4-bd15-6f05cbc0b673'},
#      {'name': 'L. BARRIOS',
#       'firstName': 'LUIS',
#       'lastName': 'BARRIOS',
#       'role': 'C',
#       'gender': 'm',
#       'nationality': 'esp',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/244e7/196340/0:0,800:800-0-0-70/fbfff',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/244e7/196340/0:0,800:800-200-0-70/4ceb6',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/6a5a6/196339/0:0,532:690-0-0-70/d2c88',
#       'aid': 'f76c0d0f-31f4-4308-8ff3-3bed03e5df84'}]}},
#   {'bib': 409,
#    'reason': '1',
#    'team': {'bib': 409,
#     'brand': 'BRP',
#     'model': 'CAN-AM MAVERICK R',
#     'vehicle': 'SOUTH RACING CAN-AM',
#     'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409/194071/0:0,600:500-0-0-70/58529',
#     'clazz': '9a68ed3c41c5c7a1642df5d93458baa6',
#     'w2rc': True,
#     'competitors': [{'name': 'F. ALVAREZ CASTELLANO',
#       'firstName': 'FERNANDO',
#       'lastName': 'ALVAREZ CASTELLANO',
#       'role': 'P',
#       'gender': 'm',
#       'nationality': 'esp',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-p/195826/0:0,800:800-0-0-70/96119',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-p/195826/0:0,800:800-200-0-70/ba4d5',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-p/192952/0:0,532:690-0-0-70/f9e1c',
#       'aid': '1c7b48f0-b7bf-46ff-898a-a5fcc9ae092b'},
#      {'name': 'X. PANSERI',
#       'firstName': 'XAVIER',
#       'lastName': 'PANSERI',
#       'role': 'C',
#       'gender': 'm',
#       'nationality': 'fra',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-c/196052/0:0,800:800-0-0-70/24567',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-c/196052/0:0,800:800-200-0-70/3b003',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-c/192946/0:0,532:690-0-0-70/06946',
#       'aid': '8cbc5c46-57f1-40c5-9702-f359372b3e7b'}]}},
#   {'bib': 416,
#    'reason': '1',
#    'team': {'bib': 416,
#     'brand': 'BRP',
#     'model': 'CAN-AM MAVERICK XRS TURBO RR',
#     'vehicle': 'OVERLIMIT',
#     'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/416/194281/0:0,600:500-0-0-70/dcc17',
#     'clazz': '058d77cc7db191813c30a902a8d5ba7c',
#     'w2rc': False,
#     'competitors': [{'name': 'G. BROCHOCKI',
#       'firstName': 'GRZEGORZ',
#       'lastName': 'BROCHOCKI',
#       'role': 'P',
#       'gender': 'm',
#       'nationality': 'pol',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/416-p/195541/0:0,800:800-0-0-70/04d70',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/416-p/195541/0:0,800:800-200-0-70/3e30c',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/416-p/192642/0:0,532:690-0-0-70/ce0ae',
#       'aid': '50b9c651-6619-4cff-bd41-311feb740386'},
#      {'name': 'G. KOMAR',
#       'firstName': 'GRZEGORZ',
#       'lastName': 'KOMAR',
#       'role': 'C',
#       'gender': 'm',
#       'nationality': 'pol',
#       'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/416-c/195543/0:0,800:800-0-0-70/6dd2e',
#       'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/416-c/195543/0:0,800:800-200-0-70/8d01d',
#       'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/416-c/192817/0:0,532:690-0-0-70/8cec5',
#       'aid': 'a5e362fa-6639-41b6-8205-a407b9d80d5c'}]}}],
#  'stage': 5}

# %%
# This breaks  on list.team.competitors.name
#cur = col.find({}, {"_id": 0, "list.reason": 1, "list.team.w2rc":1, "stage": 1, list.team.competitors.name:1})
"""
"list", {
    "reason": "2",
    "team.w2rc": True
}
"""
#next(cur)
# Out:
# '\n"list", {\n    "reason": "2",\n    "team.w2rc": True\n}\n'

# %%
[r for r in col.find({"stage": 4}, {"_id":0,"list":1, "stage":1, } )]
# Unsupported projection:  "$elemMatch": { "list.competitors.lastName": "LOEB" }
#  "list.team.competitors" :{"$elemMatch":{"role":"P"}}
#  "list":{"$elemMatch": {"competitors":{"$elemMatch": {"lastName":"LOEB"}}}}
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 [r for r in col.find({"stage": 4}, {"_id":0,"list":1, "stage":1, "list.team.competitors" :{"$elemMatch":{"role":"P"}} } )]
#       2 # Unsupported projection:  "$elemMatch": { "list.competitors.lastName": "LOEB" }
#       3 #  "list":{"$elemMatch": {"competitors":{"$elemMatch": {"lastName":"LOEB"}}}}
#
# File ~/.local/lib/python3.12/site-packages/montydb/cursor.py:365, in MontyCursor.next(self)
#     363 if self._empty:
#     364     raise StopIteration
# --> 365 if len(self._data) or self._refresh():
#     366     return self._data.popleft()
#     367 else:
#
# File ~/.local/lib/python3.12/site-packages/montydb/cursor.py:354, in MontyCursor._refresh(self)
#     350     return len(self._data)
#     352 if self._id is None:
#     353     # (NOTE) Query
# --> 354     self.__query()
#     355 elif self._id:
#     356     # (NOTE) Get More
#     357     pass
#
# File ~/.local/lib/python3.12/site-packages/montydb/cursor.py:303, in MontyCursor.__query(self)
#     301 projector = None
#     302 if self._projection:
# --> 303     projector = Projector(self._projection, queryfilter)
#     305 # Fetch from storage
#     306 # (NOTE) Documents return from storage should be decoded.
#     307 storage = self._collection.database.client._storage
#
# File ~/.local/lib/python3.12/site-packages/montydb/engine/project.py:76, in Projector.__init__(self, spec, qfilter)
#      73 self.matched = None
#      74 self.position_path = None
# ---> 76 self.parser(spec, qfilter)
#      78 if self.array_field and not self.regular_field:
#      79     self.include_flag = True
#
# File ~/.local/lib/python3.12/site-packages/montydb/engine/project.py:159, in Projector.parser(self, spec, qfilter)
#     155     raise OperationFailure(
#     156         "Cannot specify positional operator and $elemMatch."
#     157     )
#     158 if "." in key:
# --> 159     raise OperationFailure(
#     160         "Cannot use $elemMatch projection on a nested field.",
#     161         code=2,
#     162     )
#     164 self.array_op_type = self.ARRAY_OP_ELEM_MATCH
#     165 self.array_field[key] = self.parse_elemMatch(key, sub_v)
#
# OperationFailure: Cannot use $elemMatch projection on a nested field.

# %%
[r for r in col.find({"list.team.brand": 'DACIA'}, {"_id": 0})]
# Out:
# [{'_bind': 'withdrawal-2025-A',
#   '_updatedAt': 1736877547536,
#   '_parent': 'stage-2025-A:8002af597f2d091dc91450266fab52d6',
#   'list': [{'bib': 219,
#     'reason': '2',
#     'team': {'bib': 219,
#      'brand': 'DACIA',
#      'model': 'SANDRIDER',
#      'vehicle': 'THE DACIA SANDRIDERS',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219/194474/0:0,600:500-0-0-70/a91f6',
#      'clazz': '96c0869600e0013dbf5f86f60e5c4da4',
#      'w2rc': True,
#      'competitors': [{'name': 'S. LOEB',
#        'firstName': 'SEBASTIEN',
#        'lastName': 'LOEB',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'fra',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-p/195610/0:0,800:800-0-0-70/58e9a',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-p/195610/0:0,800:800-200-0-70/2340d',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-p/192891/0:0,532:690-0-0-70/cc2b4',
#        'aid': '5dd0184f-5f90-4b42-b675-88d6501b9965'},
#       {'name': 'F. LURQUIN',
#        'firstName': 'FABIAN',
#        'lastName': 'LURQUIN',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'bel',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-c/196139/0:0,800:800-0-0-70/f59f5',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-c/196139/0:0,800:800-200-0-70/09f63',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-c/192873/0:0,532:690-0-0-70/73d14',
#        'aid': 'c640056a-79d0-4454-8e6a-c8b303620020'}]}},
#    {'bib': 236,
#     'reason': '1',
#     'team': {'bib': 236,
#      'brand': 'MD',
#      'model': 'OPTIMUS',
#      'vehicle': 'MD RALLYE SPORT',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/236/193945/0:0,600:500-0-0-70/5c038',
#      'clazz': 'f00d7ec8d2d96e9cf11aa515109376cf',
#      'w2rc': False,
#      'competitors': [{'name': 'E. AMOS',
#        'firstName': 'EUGENIO',
#        'lastName': 'AMOS',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'ita',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/236-p/195474/0:0,800:800-0-0-70/8495a',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/236-p/195474/0:0,800:800-200-0-70/a23a9',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/236-p/192997/0:0,532:690-0-0-70/bc9cf',
#        'aid': '0575de36-4a38-431c-8892-ac9514c8ccd9'},
#       {'name': 'P. CECI',
#        'firstName': 'PAOLO',
#        'lastName': 'CECI',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'ita',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/236-c/195953/0:0,800:800-0-0-70/8d4d0',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/236-c/195953/0:0,800:800-200-0-70/719b6',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/236-c/192351/0:0,532:690-0-0-70/c4c32',
#        'aid': 'fdacd829-75f9-4cfa-9992-636c8244481e'}]}},
#    {'bib': 258,
#     'reason': '1',
#     'team': {'bib': 258,
#      'brand': 'RED-LINED',
#      'model': 'NAVARRA VK 56',
#      'vehicle': 'WALCHER RACING TEAM',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/258/194517/0:0,600:500-0-0-70/ad2b8',
#      'clazz': 'f666973e89db183ecfefc75c3af8ffb1',
#      'w2rc': False,
#      'competitors': [{'name': 'M. WALCHER',
#        'firstName': 'MARKUS',
#        'lastName': 'WALCHER',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'deu',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/258-p/195472/0:0,800:800-0-0-70/172d3',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/258-p/195472/0:0,800:800-200-0-70/edb17',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/258-p/192519/0:0,532:690-0-0-70/72aa2',
#        'aid': '93be84ca-0b2b-4da0-933a-e394a8a29cdb'},
#       {'name': 'F. PREUSS',
#        'firstName': 'FRANK STEPHAN',
#        'lastName': 'PREUSS',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'deu',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/258-c/195475/0:0,800:800-0-0-70/870e7',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/258-c/195475/0:0,800:800-200-0-70/87737',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/258-c/192709/0:0,532:690-0-0-70/97d38',
#        'aid': '30816b29-5600-4626-bbe3-23796ec0cbc6'}]}},
#    {'bib': 337,
#     'reason': '1',
#     'team': {'bib': 337,
#      'brand': 'BRP',
#      'model': 'CAN-AM MAVERICK X3',
#      'vehicle': 'COLORADO MOTORSPORT',
#      'clazz': 'a0a6386a4b9a61b73b036a50966345c0',
#      'w2rc': False,
#      'competitors': [{'name': 'C. LUMSDEN',
#        'firstName': 'CRAIG',
#        'lastName': 'LUMSDEN',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'usa',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/337-p/190344/0:0,800:800-0-0-70/67e18',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/337-p/190344/0:0,800:800-200-0-70/29d01',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/337-p/192212/0:0,532:690-0-0-70/97444',
#        'aid': '1523f846-8459-491e-841b-f56fb81203e4'},
#       {'name': 'J. LAMBERT',
#        'firstName': 'JAMIE',
#        'lastName': 'LAMBERT',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'usa',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/337-c/190379/0:0,800:800-0-0-70/d4f3d',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/337-c/190379/0:0,800:800-200-0-70/f93ee',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/337-c/190835/0:0,532:690-0-0-70/6b17d',
#        'aid': '1700a0eb-642f-4118-91c1-eb9cd6efad89'}]}},
#    {'bib': 408,
#     'reason': '1',
#     'team': {'bib': 408,
#      'brand': 'BRP',
#      'model': 'CAN-AM MAVERICK R',
#      'vehicle': 'SOUTH RACING CAN-AM',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408/194444/0:0,600:500-0-0-70/bac3a',
#      'clazz': '9a68ed3c41c5c7a1642df5d93458baa6',
#      'w2rc': True,
#      'competitors': [{'name': 'D. MARTINEZ',
#        'firstName': 'DIEGO',
#        'lastName': 'MARTINEZ',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'arg',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-p/195898/0:0,800:800-0-0-70/d8086',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-p/195898/0:0,800:800-200-0-70/2d81d',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-p/192958/0:0,532:690-0-0-70/aa124',
#        'aid': '122c1cd5-3712-4b97-84cb-ab7cf9beeeeb'},
#       {'name': 'S. LAFUENTE',
#        'firstName': 'SERGIO',
#        'lastName': 'LAFUENTE',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'ury',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-c/196074/0:0,800:800-0-0-70/a39a0',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-c/196074/0:0,800:800-200-0-70/3377d',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-c/192355/0:0,532:690-0-0-70/42e4e',
#        'aid': 'e6c76669-52d8-4c10-98b2-360b79967edc'}]}},
#    {'bib': 432,
#     'reason': '1',
#     'team': {'bib': 432,
#      'brand': 'BRP',
#      'model': 'CAN-AM MAVERICK XRS TURBO RR',
#      'vehicle': 'PEDREGÀ TEAM',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/432/194004/0:0,600:500-0-0-70/deb69',
#      'clazz': '058d77cc7db191813c30a902a8d5ba7c',
#      'w2rc': False,
#      'competitors': [{'name': 'J. VIDAÑA',
#        'firstName': 'JOSE',
#        'lastName': 'VIDAÑA',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'esp',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/432-p/195553/0:0,800:800-0-0-70/27ca6',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/432-p/195553/0:0,800:800-200-0-70/0664a',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/432-p/192980/0:0,532:690-0-0-70/a03ea',
#        'aid': 'cd9afc18-6ade-427c-b5c9-e24568880d36'},
#       {'name': 'M. GARRIDO',
#        'firstName': 'MARIO',
#        'lastName': 'GARRIDO',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'esp',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/432-c/195555/0:0,800:800-0-0-70/a221d',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/432-c/195555/0:0,800:800-200-0-70/280ef',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/432-c/191921/0:0,532:690-0-0-70/bba64',
#        'aid': '924ded4c-d2ae-4166-95aa-dd9791f9426d'}]}},
#    {'bib': 439,
#     'reason': '1',
#     'team': {'bib': 439,
#      'brand': 'BRP',
#      'model': 'CAN-AM MAVERICK XRS TURBO RR',
#      'vehicle': 'PEDREGÀ TEAM',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/439/193909/0:0,600:500-0-0-70/597fe',
#      'clazz': '058d77cc7db191813c30a902a8d5ba7c',
#      'w2rc': False,
#      'competitors': [{'name': 'R. MUÑOZ CAMARA',
#        'firstName': 'RAFA',
#        'lastName': 'MUÑOZ CAMARA',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'esp',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/439-p/195566/0:0,800:800-0-0-70/83b10',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/439-p/195566/0:0,800:800-200-0-70/faa87',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/439-p/192675/0:0,532:690-0-0-70/50dc4',
#        'aid': 'c6025530-5684-4808-84d1-dfc9c561c154'},
#       {'name': 'D. CAMARA ORDOÑEZ',
#        'firstName': 'DANI',
#        'lastName': 'CAMARA ORDOÑEZ',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'esp',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/439-c/195559/0:0,800:800-0-0-70/7efe4',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/439-c/195559/0:0,800:800-200-0-70/06299',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/439-c/192646/0:0,532:690-0-0-70/95d1f',
#        'aid': 'e75bda4c-cad7-4a8a-be39-8523240bc071'}]}},
#    {'bib': 609,
#     'reason': '1',
#     'team': {'bib': 609,
#      'brand': 'IVECO',
#      'model': 'POWERSTAR',
#      'vehicle': 'De Groot Sport',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609/193910/0:0,600:500-0-0-70/931f5',
#      'clazz': 'fa2b8d6b8d84480b3fd11a2fd829b2d6',
#      'w2rc': False,
#      'competitors': [{'name': 'B. DE GROOT',
#        'firstName': 'BEN',
#        'lastName': 'DE GROOT',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'nld',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609-p/195761/0:0,800:800-0-0-70/0d6ba',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609-p/195761/0:0,800:800-200-0-70/c84fa',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609-p/192930/0:0,532:690-0-0-70/efe89',
#        'aid': '2583d80c-22d3-410b-a59c-227eb3c02ef0'},
#       {'name': 'A. HOFMANS',
#        'firstName': 'AD',
#        'lastName': 'HOFMANS',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'nld',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609-c/196003/0:0,800:800-0-0-70/0c613',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609-c/196003/0:0,800:800-200-0-70/65241',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609-c/191132/0:0,532:690-0-0-70/02cb7',
#        'aid': '5baa7eac-d29d-4bf6-bac3-b4464f033447'},
#       {'name': 'G. BOOGAARD',
#        'firstName': 'GOVERT',
#        'lastName': 'BOOGAARD',
#        'role': 'M',
#        'gender': 'm',
#        'nationality': 'nld',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609-m/196160/0:0,800:800-0-0-70/3b118',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609-m/196160/0:0,800:800-200-0-70/32d4a',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/609-m/192897/0:0,532:690-0-0-70/c91f9',
#        'aid': '5fef8d34-87ab-45d3-a70c-2bbf3276e0a5'}]}}],
#   'stage': 4}]

# %% [markdown]
# __TO DO__ start to build up pipeline operator from scratch; need $unwind , $match, $project

# %%
from typing import List, Dict, Any, Union, Callable
import operator
from datetime import datetime

# ??DEPRECATE THIS ONE????

class MontyFilter:
    """
    A class to extend MontyDB with MongoDB-style filtering capabilities.
    """

    def __init__(self, collection):
        self.collection = collection
        self.operators = {
            "$eq": operator.eq,
            "$ne": operator.ne,
            "$gt": operator.gt,
            "$gte": operator.ge,
            "$lt": operator.lt,
            "$lte": operator.le,
            "$in": lambda x, y: x in y,
            "$nin": lambda x, y: x not in y,
            "$exists": lambda x, y: (x is not None) == y,
            "$type": lambda x, y: isinstance(x, self._get_type(y)),
            "$regex": lambda x, y: bool(re.search(y, x)) if isinstance(x, str) else False
        }

    def _get_type(self, type_name: str) -> type:
        """Map MongoDB type names to Python types."""
        type_map = {
            "string": str,
            "number": (int, float),
            "boolean": bool,
            "date": datetime,
            "array": list,
            "object": dict,
            "null": type(None)
        }
        return type_map.get(type_name, object)

    def _get_nested_value(self, obj: Dict, path: str) -> Any:
        """Get value from nested dictionary using dot notation."""
        parts = path.split('.')
        current = obj
        for part in parts:
            if isinstance(current, dict):
                current = current.get(part)
            elif isinstance(current, list) and part.isdigit():
                current = current[int(part)] if int(
                    part) < len(current) else None
            else:
                return None
            if current is None:
                return None
        return current

    def _apply_operator(self, value: Any, condition: Dict) -> bool:
        """Apply MongoDB-style operators to a value."""
        for op, comparison in condition.items():
            if op not in self.operators:
                raise ValueError(f"Unsupported operator: {op}")
            if not self.operators[op](value, comparison):
                return False
        return True

    def _evaluate_condition(self, doc: Dict, condition: Dict) -> bool:
        """Evaluate a condition against a document."""
        for field, value in condition.items():
            if field.startswith('$'):
                # Handle logical operators
                if field == '$and':
                    if not all(self._evaluate_condition(doc, cond) for cond in value):
                        return False
                elif field == '$or':
                    if not any(self._evaluate_condition(doc, cond) for cond in value):
                        return False
                elif field == '$not':
                    if self._evaluate_condition(doc, value):
                        return False
            else:
                # Handle field conditions
                actual_value = self._get_nested_value(doc, field)
                if isinstance(value, dict):
                    if not self._apply_operator(actual_value, value):
                        return False
                else:
                    if actual_value != value:
                        return False
        return True

    def filter_array(self, array_field: str, conditions: Dict) -> List[Dict]:
        """
        Filter array elements within documents based on conditions.
        
        Args:
            array_field: The field containing the array to filter
            conditions: MongoDB-style query conditions
            
        Returns:
            List of documents with filtered arrays
        """
        results = []
        for doc in self.collection.find():
            array_data = self._get_nested_value(doc, array_field)
            if not isinstance(array_data, list):
                continue

            filtered_array = [
                item for item in array_data
                if self._evaluate_condition(item, conditions)
            ]

            if filtered_array:
                new_doc = doc.copy()
                current = new_doc
                parts = array_field.split('.')
                for part in parts[:-1]:
                    current = current[part]
                current[parts[-1]] = filtered_array
                results.append(new_doc)

        return results

    def find(self, conditions: Dict) -> List[Dict]:
        """
        Find documents matching the given conditions.
        
        Args:
            conditions: MongoDB-style query conditions
            
        Returns:
            List of matching documents
        """
        return [
            doc for doc in self.collection.find()
            if self._evaluate_condition(doc, conditions)
        ]

# Example usage class for demonstration


class FilterExample:
    def __init__(self, collection):
        self.filter = MontyFilter(collection)

    def filter_by_reason(self, reason: str) -> List[Dict]:
        """Filter list items by reason."""
        return self.filter.filter_array("list", {"reason": reason})

    def filter_by_brand(self, brand: str) -> List[Dict]:
        """Filter list items by team brand."""
        return self.filter.filter_array("list", {"team.brand": brand})

    def complex_filter(self) -> List[Dict]:
        """Example of a complex filter."""
        conditions = {
            "$and": [
                {"team.w2rc": True},
                {"$or": [
                    {"team.brand": "DACIA"},
                    {"team.brand": "TOYOTA"}
                ]}
            ]
        }
        return self.filter.filter_array("list", conditions)


# Usage example:
"""
# Initialize
client = montydb.MontyClient('path/to/db')
db = client.your_database
collection = db.your_collection
filter_helper = FilterExample(collection)

# Simple filtering
dacia_entries = filter_helper.filter_by_brand("DACIA")

# Complex filtering
w2rc_entries = filter_helper.complex_filter()

# Custom filtering using MontyFilter directly
monty_filter = MontyFilter(collection)
custom_filtered = monty_filter.filter_array("list", {
    "reason": "2",
    "team.w2rc": True,
    "team.competitors": {
        "$exists": True
    }
})
"""
# Out:
# '\n# Initialize\nclient = montydb.MontyClient(\'path/to/db\')\ndb = client.your_database\ncollection = db.your_collection\nfilter_helper = FilterExample(collection)\n\n# Simple filtering\ndacia_entries = filter_helper.filter_by_brand("DACIA")\n\n# Complex filtering\nw2rc_entries = filter_helper.complex_filter()\n\n# Custom filtering using MontyFilter directly\nmonty_filter = MontyFilter(collection)\ncustom_filtered = monty_filter.filter_array("list", {\n    "reason": "2",\n    "team.w2rc": True,\n    "team.competitors": {\n        "$exists": True\n    }\n})\n'

# %%
# DEPRECATED
filter_helper = FilterExample(col)

# Simple filtering
dacia_entries = filter_helper.filter_by_brand("DACIA")
dacia_entries
# Out:
# [{'_id': 'withdrawal-2025-A-4',
#   '_bind': 'withdrawal-2025-A',
#   '_updatedAt': 1736877547536,
#   '_parent': 'stage-2025-A:8002af597f2d091dc91450266fab52d6',
#   'list': [{'bib': 219,
#     'reason': '2',
#     'team': {'bib': 219,
#      'brand': 'DACIA',
#      'model': 'SANDRIDER',
#      'vehicle': 'THE DACIA SANDRIDERS',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219/194474/0:0,600:500-0-0-70/a91f6',
#      'clazz': '96c0869600e0013dbf5f86f60e5c4da4',
#      'w2rc': True,
#      'competitors': [{'name': 'S. LOEB',
#        'firstName': 'SEBASTIEN',
#        'lastName': 'LOEB',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'fra',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-p/195610/0:0,800:800-0-0-70/58e9a',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-p/195610/0:0,800:800-200-0-70/2340d',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-p/192891/0:0,532:690-0-0-70/cc2b4',
#        'aid': '5dd0184f-5f90-4b42-b675-88d6501b9965'},
#       {'name': 'F. LURQUIN',
#        'firstName': 'FABIAN',
#        'lastName': 'LURQUIN',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'bel',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-c/196139/0:0,800:800-0-0-70/f59f5',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-c/196139/0:0,800:800-200-0-70/09f63',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-c/192873/0:0,532:690-0-0-70/73d14',
#        'aid': 'c640056a-79d0-4454-8e6a-c8b303620020'}]}}],
#   'stage': 4}]

# %%
# DEPRECATED
monty_filter = MontyFilter(col)
custom_filtered = monty_filter.filter_array("list", {
    "reason": "1",
    "team.w2rc": True,
    "team.competitors": {
        "$exists": True
    }
})
custom_filtered
# Out:
# [{'_id': 'withdrawal-2025-A-5',
#   '_bind': 'withdrawal-2025-A',
#   '_updatedAt': 1736877542722,
#   '_parent': 'stage-2025-A:e2b95b95a4ae9063eb4924fc2d7cf7e7',
#   'list': [{'bib': 309,
#     'reason': '1',
#     'team': {'bib': 309,
#      'brand': 'TAURUS',
#      'model': 'T3 MAX',
#      'vehicle': 'NASSER RACING',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309/194406/0:0,600:500-0-0-70/b16a2',
#      'clazz': 'a0a6386a4b9a61b73b036a50966345c0',
#      'w2rc': True,
#      'competitors': [{'name': 'E. PONS',
#        'firstName': 'EDUARD',
#        'lastName': 'PONS',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'esp',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-p/195921/0:0,800:800-0-0-70/760ed',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-p/195921/0:0,800:800-200-0-70/d21d9',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-p/192526/0:0,532:690-0-0-70/b071c',
#        'aid': 'a3da2c1f-22cb-4ec6-91cd-8219d543c478'},
#       {'name': 'J. BETRIU',
#        'firstName': 'JAUME',
#        'lastName': 'BETRIU',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'esp',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-c/196102/0:0,800:800-0-0-70/bb562',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-c/196102/0:0,800:800-200-0-70/0506a',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/309-c/192823/0:0,532:690-0-0-70/ec2a7',
#        'aid': '6e68a900-0a4a-41d7-b852-cbc75e4ff2a4'}]}},
#    {'bib': 409,
#     'reason': '1',
#     'team': {'bib': 409,
#      'brand': 'BRP',
#      'model': 'CAN-AM MAVERICK R',
#      'vehicle': 'SOUTH RACING CAN-AM',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409/194071/0:0,600:500-0-0-70/58529',
#      'clazz': '9a68ed3c41c5c7a1642df5d93458baa6',
#      'w2rc': True,
#      'competitors': [{'name': 'F. ALVAREZ CASTELLANO',
#        'firstName': 'FERNANDO',
#        'lastName': 'ALVAREZ CASTELLANO',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'esp',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-p/195826/0:0,800:800-0-0-70/96119',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-p/195826/0:0,800:800-200-0-70/ba4d5',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-p/192952/0:0,532:690-0-0-70/f9e1c',
#        'aid': '1c7b48f0-b7bf-46ff-898a-a5fcc9ae092b'},
#       {'name': 'X. PANSERI',
#        'firstName': 'XAVIER',
#        'lastName': 'PANSERI',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'fra',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-c/196052/0:0,800:800-0-0-70/24567',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-c/196052/0:0,800:800-200-0-70/3b003',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/409-c/192946/0:0,532:690-0-0-70/06946',
#        'aid': '8cbc5c46-57f1-40c5-9702-f359372b3e7b'}]}}],
#   'stage': 5},
#  {'_id': 'withdrawal-2025-A-3',
#   '_bind': 'withdrawal-2025-A',
#   '_updatedAt': 1736877554109,
#   '_parent': 'stage-2025-A:127ed31c3eff071ba6a7e88fe01083ef',
#   'list': [{'bib': 225,
#     'reason': '1',
#     'team': {'bib': 225,
#      'brand': 'FORD',
#      'model': 'RAPTOR',
#      'vehicle': 'FORD M-SPORT',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/225/194421/0:0,600:500-0-0-70/ff426',
#      'clazz': '96c0869600e0013dbf5f86f60e5c4da4',
#      'w2rc': True,
#      'competitors': [{'name': 'C. SAINZ',
#        'firstName': 'CARLOS',
#        'lastName': 'SAINZ',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'esp',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/225-p/195605/0:0,800:800-0-0-70/69df0',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/225-p/195605/0:0,800:800-200-0-70/0a1cc',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/225-p/192517/0:0,532:690-0-0-70/9e0df',
#        'aid': 'bcf87d86-94ea-4e42-8ef1-40ab457a7722'},
#       {'name': 'L. CRUZ',
#        'firstName': 'LUCAS',
#        'lastName': 'CRUZ',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'esp',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/225-c/195923/0:0,800:800-0-0-70/e4dfc',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/225-c/195923/0:0,800:800-200-0-70/d6579',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/225-c/192913/0:0,532:690-0-0-70/58116',
#        'aid': 'a18dcfe7-4905-4bbe-bfff-e00b94c6b734'}]}},
#    {'bib': 313,
#     'reason': '1',
#     'team': {'bib': 313,
#      'brand': 'TAURUS',
#      'model': 'T3 MAX',
#      'vehicle': 'ALJAFLA RACING',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/313/194402/0:0,600:500-0-0-70/6eaf0',
#      'clazz': 'a0a6386a4b9a61b73b036a50966345c0',
#      'w2rc': True,
#      'competitors': [{'name': 'K. ALJAFLA',
#        'firstName': 'KHALID',
#        'lastName': 'ALJAFLA',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'are',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/313-p/195780/0:0,800:800-0-0-70/5bdd0',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/313-p/195780/0:0,800:800-200-0-70/d3da5',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/313-p/192753/0:0,532:690-0-0-70/dc437',
#        'aid': 'f598c7f5-ca00-4945-8ccb-0888487460c7'},
#       {'name': 'A. RUDNITSKI',
#        'firstName': 'ANDREI',
#        'lastName': 'RUDNITSKI',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'blr',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/313-c/196137/0:0,800:800-0-0-70/fdcf8',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/313-c/196137/0:0,800:800-200-0-70/a9e57',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/313-c/192838/0:0,532:690-0-0-70/53a28',
#        'aid': '94cc1952-01af-46c7-b4ae-2ba8b50299a2'}]}}],
#   'stage': 3},
#  {'_id': 'withdrawal-2025-A-9',
#   '_bind': 'withdrawal-2025-A',
#   '_updatedAt': 1736943602310,
#   '_parent': 'stage-2025-A:5f83172bf9f0bb97d14b83a7c0099fa8',
#   'list': [{'bib': 321,
#     'reason': '1',
#     'team': {'bib': 321,
#      'brand': 'GRALLYTEAM',
#      'model': 'OT3',
#      'vehicle': 'G Rally Team',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/321/194405/0:0,600:500-0-0-70/a01be',
#      'clazz': 'a0a6386a4b9a61b73b036a50966345c0',
#      'w2rc': True,
#      'competitors': [{'name': 'R. CARNEIRO',
#        'firstName': 'RUI',
#        'lastName': 'CARNEIRO',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'prt',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/321-p/195762/0:0,800:800-0-0-70/edb40',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/321-p/195762/0:0,800:800-200-0-70/b4261',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/321-p/192822/0:0,532:690-0-0-70/33593',
#        'aid': 'b543412c-d76e-4317-93a2-76c65e17f451'},
#       {'name': 'O. FLOENE',
#        'firstName': 'OLA',
#        'lastName': 'FLOENE',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'nor',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/321-c/196100/0:0,800:800-0-0-70/44a8e',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/321-c/196100/0:0,800:800-200-0-70/51340',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/321-c/192801/0:0,532:690-0-0-70/6a474',
#        'aid': '60c32fbf-5947-4bda-9356-96780af132a8'}]}}],
#   'stage': 9},
#  {'_id': 'withdrawal-2025-A-4',
#   '_bind': 'withdrawal-2025-A',
#   '_updatedAt': 1736877547536,
#   '_parent': 'stage-2025-A:8002af597f2d091dc91450266fab52d6',
#   'list': [{'bib': 408,
#     'reason': '1',
#     'team': {'bib': 408,
#      'brand': 'BRP',
#      'model': 'CAN-AM MAVERICK R',
#      'vehicle': 'SOUTH RACING CAN-AM',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408/194444/0:0,600:500-0-0-70/bac3a',
#      'clazz': '9a68ed3c41c5c7a1642df5d93458baa6',
#      'w2rc': True,
#      'competitors': [{'name': 'D. MARTINEZ',
#        'firstName': 'DIEGO',
#        'lastName': 'MARTINEZ',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'arg',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-p/195898/0:0,800:800-0-0-70/d8086',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-p/195898/0:0,800:800-200-0-70/2d81d',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-p/192958/0:0,532:690-0-0-70/aa124',
#        'aid': '122c1cd5-3712-4b97-84cb-ab7cf9beeeeb'},
#       {'name': 'S. LAFUENTE',
#        'firstName': 'SERGIO',
#        'lastName': 'LAFUENTE',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'ury',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-c/196074/0:0,800:800-0-0-70/a39a0',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-c/196074/0:0,800:800-200-0-70/3377d',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/408-c/192355/0:0,532:690-0-0-70/42e4e',
#        'aid': 'e6c76669-52d8-4c10-98b2-360b79967edc'}]}}],
#   'stage': 4}]

# %% [markdown]
# TO DO - in the following, `filter_array()` first queries everything using `self.collection.find()`; really, we should have a step before that with an actual query, eg as a pipleline stage, and then pass that in?

# %%
from typing import List, Dict, Any, Union, Callable, Optional
import operator
from datetime import datetime
import copy


class MontyFilter:
    def __init__(self, collection):
        self.collection = collection
        self.operators = {
            "$eq": operator.eq,
            "$ne": operator.ne,
            "$gt": operator.gt,
            "$gte": operator.ge,
            "$lt": operator.lt,
            "$lte": operator.le,
            "$in": lambda x, y: x in y,
            "$nin": lambda x, y: x not in y,
            "$exists": lambda x, y: (x is not None) == y,
            "$type": lambda x, y: isinstance(x, self._get_type(y)),
            "$regex": lambda x, y: bool(re.search(y, x)) if isinstance(x, str) else False
        }

    def _get_type(self, type_name: str) -> type:
        type_map = {
            "string": str,
            "number": (int, float),
            "boolean": bool,
            "date": datetime,
            "array": list,
            "object": dict,
            "null": type(None)
        }
        return type_map.get(type_name, object)

    def _get_nested_value(self, obj: Dict, path: str) -> Any:
        parts = path.split('.')
        current = obj
        for part in parts:
            if isinstance(current, dict):
                current = current.get(part)
            elif isinstance(current, list) and part.isdigit():
                current = current[int(part)] if int(
                    part) < len(current) else None
            else:
                return None
            if current is None:
                return None
        return current

    def _apply_operator(self, value: Any, condition: Dict) -> bool:
        for op, comparison in condition.items():
            if op not in self.operators:
                raise ValueError(f"Unsupported operator: {op}")
            if not self.operators[op](value, comparison):
                return False
        return True

    def _evaluate_condition(self, doc: Dict, condition: Dict) -> bool:
        for field, value in condition.items():
            if field.startswith('$'):
                if field == '$and':
                    if not all(self._evaluate_condition(doc, cond) for cond in value):
                        return False
                elif field == '$or':
                    if not any(self._evaluate_condition(doc, cond) for cond in value):
                        return False
                elif field == '$not':
                    if self._evaluate_condition(doc, value):
                        return False
            else:
                actual_value = self._get_nested_value(doc, field)
                if isinstance(value, dict):
                    if not self._apply_operator(actual_value, value):
                        return False
                else:
                    if actual_value != value:
                        return False
        return True

    def _keep_fields(self, doc: Dict, fields: List[str]) -> Dict:
        """Simple field filtering - keep only specified fields and their parents"""
        if not fields:
            return doc

        result = {'_id': doc.get('_id')}  # Always keep _id

        # For each field we want to keep
        for field in fields:
            parts = field.split('.')
            value = doc  # Start at the root
            temp_dict = result

            # Walk through the parts
            for i, part in enumerate(parts):
                if value is None or not isinstance(value, dict):
                    break

                # Get the value for this part
                value = value.get(part)

                # If it's not the last part, ensure the path exists
                if i < len(parts) - 1:
                    if part not in temp_dict:
                        temp_dict[part] = {}
                    temp_dict = temp_dict[part]
                # If it's the last part, set the value
                else:
                    temp_dict[part] = value

        return result

    def filter_array(self, array_field: str, conditions: Dict, fields: List[str] = None) -> List[Dict]:
        """
        Filter array elements within documents based on conditions.
        
        Args:
            array_field: The field containing the array to filter
            conditions: MongoDB-style query conditions
            fields: Optional list of fields to keep in the result
            
        Returns:
            List of documents with filtered arrays
        """
        results = []
        # First do the filtering
        for doc in self.collection.find():
            array_data = self._get_nested_value(doc, array_field)
            if not isinstance(array_data, list):
                continue

            filtered_array = [
                item for item in array_data
                if self._evaluate_condition(item, conditions)
            ]

            if filtered_array:
                new_doc = doc.copy()
                current = new_doc
                parts = array_field.split('.')
                for part in parts[:-1]:
                    current = current[part]
                current[parts[-1]] = filtered_array

                # If fields are specified, filter them
                if fields:
                    # Make sure to include the array field in the fields list
                    if array_field not in fields:
                        fields.append(array_field)
                    new_doc = self._keep_fields(new_doc, fields)

                results.append(new_doc)

        return results


# Example usage:
"""
monty_filter = MontyFilter(collection)

# Basic filtering (original working version)
filtered_docs = monty_filter.filter_array("list", {
    "reason": "2",
    "team.w2rc": True
})

# With field projection
filtered_docs = monty_filter.filter_array(
    array_field="list",
    conditions={"reason": "2"},
    fields=["list", "list.reason", "list.team.brand"]  # Note: 'list' is included automatically
)
"""
# Out:
# '\nmonty_filter = MontyFilter(collection)\n\n# Basic filtering (original working version)\nfiltered_docs = monty_filter.filter_array("list", {\n    "reason": "2",\n    "team.w2rc": True\n})\n\n# With field projection\nfiltered_docs = monty_filter.filter_array(\n    array_field="list",\n    conditions={"reason": "2"},\n    fields=["list", "list.reason", "list.team.brand"]  # Note: \'list\' is included automatically\n)\n'

# %%
monty_filter = MontyFilter(col)

# Basic filtering (original working version)
filtered_docs = monty_filter.filter_array("list", {
    "reason": "2",
    "team.w2rc": True
})

filtered_docs
# Out:
# [{'_id': 'withdrawal-2025-A-4',
#   '_bind': 'withdrawal-2025-A',
#   '_updatedAt': 1736877547536,
#   '_parent': 'stage-2025-A:8002af597f2d091dc91450266fab52d6',
#   'list': [{'bib': 219,
#     'reason': '2',
#     'team': {'bib': 219,
#      'brand': 'DACIA',
#      'model': 'SANDRIDER',
#      'vehicle': 'THE DACIA SANDRIDERS',
#      'vehicleImg': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219/194474/0:0,600:500-0-0-70/a91f6',
#      'clazz': '96c0869600e0013dbf5f86f60e5c4da4',
#      'w2rc': True,
#      'competitors': [{'name': 'S. LOEB',
#        'firstName': 'SEBASTIEN',
#        'lastName': 'LOEB',
#        'role': 'P',
#        'gender': 'm',
#        'nationality': 'fra',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-p/195610/0:0,800:800-0-0-70/58e9a',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-p/195610/0:0,800:800-200-0-70/2340d',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-p/192891/0:0,532:690-0-0-70/cc2b4',
#        'aid': '5dd0184f-5f90-4b42-b675-88d6501b9965'},
#       {'name': 'F. LURQUIN',
#        'firstName': 'FABIAN',
#        'lastName': 'LURQUIN',
#        'role': 'C',
#        'gender': 'm',
#        'nationality': 'bel',
#        'profil': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-c/196139/0:0,800:800-0-0-70/f59f5',
#        'profil_sm': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-c/196139/0:0,800:800-200-0-70/09f63',
#        'podium': 'https://img.aso.fr/core_app/img-motorSports-dak-png/219-c/192873/0:0,532:690-0-0-70/73d14',
#        'aid': 'c640056a-79d0-4454-8e6a-c8b303620020'}]}}],
#   'stage': 4}]

# %%
# TO DO  - use this - doesn't select everything in find
# ALSO - need to be able to use find in pipleline and then pass to this?

    def filter_array(self, array_field: str, conditions: Dict, base_query: Dict = None, fields: List[str] = None) -> List[Dict]:
        """
        Filter array elements within documents based on conditions.
        
        Args:
            array_field: The field containing the array to filter
            conditions: MongoDB-style query conditions for array elements
            base_query: Optional base query to pre-filter documents before array filtering
            fields: Optional list of fields to keep in the result
            
        Returns:
            List of documents with filtered arrays
        """
        results = []
        # Use the base query if provided, otherwise get all documents
        base_query = base_query or {}
        
        # First do the filtering
        for doc in self.collection.find(base_query):
            array_data = self._get_nested_value(doc, array_field)
            if not isinstance(array_data, list):
                continue

            filtered_array = [
                item for item in array_data
                if self._evaluate_condition(item, conditions)
            ]

            if filtered_array:
                new_doc = doc.copy()
                current = new_doc
                parts = array_field.split('.')
                for part in parts[:-1]:
                    current = current[part]
                current[parts[-1]] = filtered_array

                # If fields are specified, filter them
                if fields:
                    # Make sure to include the array field in the fields list
                    if array_field not in fields:
                        fields.append(array_field)
                    new_doc = self._keep_fields(new_doc, fields)

                results.append(new_doc)

        return results


"""
monty_filter = MontyFilter(collection)

# Basic filtering with base query
filtered_docs = monty_filter.filter_array(
    array_field="list",
    conditions={"reason": "2"},
    base_query={"status": "active"}  # Pre-filter documents
)

# With field projection and base query
filtered_docs = monty_filter.filter_array(
    array_field="list",
    conditions={"reason": "2"},
    base_query={"status": "active"},
    fields=["list.reason", "list.team.brand"]
)
"""

# %%
# DEPRECATE AND USE BELOW project_fields2 
def project_fields(doc: Dict, projection: Dict) -> Dict:
    """
    Project specific fields from a document based on a MongoDB-style projection.
    
    Args:
        doc: The document to project fields from
        projection: Dict with field paths as keys and 1 as values for inclusion
        
    Returns:
        Dict containing only the specified fields with their original structure
    """
    def _project_value(obj: Any, field_paths: Dict[str, List[str]]) -> Any:
        if obj is None:
            return None

        if isinstance(obj, list):
            return [_project_value(item, field_paths) for item in obj]

        if not isinstance(obj, dict):
            return obj

        result = {}
        for prefix, remaining_paths in field_paths.items():
            if prefix not in obj:
                continue

            if not remaining_paths:
                result[prefix] = obj[prefix]
            else:
                nested_paths = {}
                for path in remaining_paths:
                    parts = path.split('.', 1)
                    if len(parts) == 1:
                        nested_paths[parts[0]] = []
                    else:
                        if parts[0] not in nested_paths:
                            nested_paths[parts[0]] = []
                        nested_paths[parts[0]].append(parts[1])

                projected = _project_value(obj[prefix], nested_paths)
                if projected is not None:
                    result[prefix] = projected

        return result if result else None

    # Organize projection paths
    field_paths = {}
    for path, include in projection.items():
        if include != 1:
            continue

        parts = path.split('.', 1)
        if parts[0] not in field_paths:
            field_paths[parts[0]] = []
        if len(parts) > 1:
            field_paths[parts[0]].append(parts[1])

    # Start projection from root
    result = _project_value(doc, field_paths)

    # Always include _id
    if isinstance(result, dict):
        result['_id'] = doc.get('_id')
    else:
        result = {'_id': doc.get('_id')}

    return result

# %%
# project specific fields
projection = {
    "list.team.competitors.name": 1,
    "list.team.bib": 1
}

# Apply projection to each filtered document
projected_docs = [project_fields(doc, projection) for doc in filtered_docs]
projected_docs
# Out:
# [{'list': [{'team': {'competitors': [{'name': 'S. LOEB'},
#       {'name': 'F. LURQUIN'}],
#      'bib': 219}}],
#   '_id': 'withdrawal-2025-A-4'}]

# %% [markdown]
# try with exclusion operator also
#
# > Exclusion projections are the opposite of inclusion projections - instead of specifying which fields you want to keep (with 1), you specify which fields you want to exclude (with 0).
# >
# > Key features of exclusion projections:
# >
# > - You can specify which fields to remove instead of which to keep
# > - Useful when you want to keep most fields and only remove a few
# > - Cannot be mixed with inclusion projections (except for _id field)
# > - The _id field is always included by default unless explicitly excluded
# > - In exclusion mode, unspecified fields are kept (opposite of inclusion mode)

# %%
#Need to add self when used in class
def project_fields2( doc: Dict, projection: Dict) -> Dict:
    """
    Project specific fields from a document based on a MongoDB-style projection.
    
    Args:
        doc: The document to project fields from
        projection: Dict with field paths as keys and 1/0 as values for inclusion/exclusion
        
    Returns:
        Dict containing only the specified fields with their original structure
    """
    def _get_nested_value(obj: Dict, path: List[str]) -> Any:
        """Get value at nested path"""
        current = obj
        for part in path:
            if isinstance(current, dict):
                if part not in current:
                    return None
                current = current[part]
            elif isinstance(current, list):
                current = [_get_nested_value(item, [part]) for item in current]
                current = [item for item in current if item is not None]
                if not current:
                    return None
            else:
                return None
        return current

    def _set_nested_value(result: Dict, path: List[str], value: Any) -> None:
        """Set value at nested path, creating intermediate dicts as needed"""
        current = result
        for part in path[:-1]:
            if part not in current:
                current[part] = {}
            current = current[part]
        current[path[-1]] = value

    # Start with empty result
    result = {}
    
    # Handle non-_id fields
    for field_path, include in projection.items():
        if field_path == '_id':
            continue
            
        if include != 1:  # Skip if not inclusion
            continue
            
        path_parts = field_path.split('.')
        value = _get_nested_value(doc, path_parts)
        
        if value is not None:
            _set_nested_value(result, path_parts, value)
    
    # Handle _id separately
    if projection.get('_id', 1) == 1:
        result['_id'] = doc.get('_id')
        
    return result

# %%
# project specific fields
projection = {
    "list.team.competitors.name": 1,
    "list.team.bib": 1,"_id":0
}

# Apply projection to each filtered document
projected_docs = [project_fields2(doc, projection) for doc in filtered_docs]
projected_docs
# Out:
# [{'list': {'team': {'competitors': {'name': [['S. LOEB', 'F. LURQUIN']]},
#     'bib': [219]}}}]

# %%
# Not tried yet - pipeline
from typing import List, Dict, Any, Callable, Union
from functools import reduce


class MontyPipeline:
    """Pipeline operator for chaining MontyFilter operations"""

    def __init__(self, collection):
        self.collection = collection
        self.filter = MontyFilter(collection)

    class Operation:
        def __init__(self, func: Callable, args: tuple, kwargs: dict):
            self.func = func
            self.args = args
            self.kwargs = kwargs

        def __call__(self, docs):
            return self.func(*self.args, **self.kwargs)

    def filter_array(self, array_field: str, conditions: Dict) -> 'Operation':
        """Create a filter array operation"""
        def _filter(docs=None):
            if docs is None:
                return self.filter.filter_array(array_field, conditions)
            # If we have incoming docs, create a temporary collection wrapper
            temp_filter = MontyFilter(
                type('TempCollection', (), {'find': lambda: docs})())
            return temp_filter.filter_array(array_field, conditions)
        return self.Operation(_filter, (), {})

    def project(self, projection: Dict) -> 'Operation':
        """Create a project operation"""
        def _project(docs):
            return [self.filter.project_fields(doc, projection) for doc in docs]
        return self.Operation(_project, (), {})

    def execute(self, operations: List[Operation]) -> List[Dict]:
        """Execute a pipeline of operations"""
        def _apply_operation(docs, operation):
            return operation(docs)

        # Start with None for the first operation to handle initial collection access
        return reduce(_apply_operation, operations, None)

# Helper function to make pipeline creation more readable


def pipeline(collection, operations: List[Operation]) -> List[Dict]:
    """Create and execute a pipeline of operations"""
    return MontyPipeline(collection).execute(operations)

# %% [markdown]
# # Simple usage
#
# ```python
# result = pipeline(collection, [
#     MontyPipeline(collection).filter_array("list", {
#         "reason": "2",
#         "team.w2rc": True
#     }),
#     MontyPipeline(collection).project({
#         "list.team.competitors.name": 1,
#         "list.team.bib": 1,
#         "_id": 0
#     })
# ])
#
# # Or create a pipeline instance for multiple uses
# mp = MontyPipeline(collection)
# result = pipeline(collection, [
#     mp.filter_array("list", {"reason": "2", "team.w2rc": True}),
#     mp.project({
#         "list.team.competitors.name": 1,
#         "list.team.bib": 1,
#         "_id": 0
#     })
# ])
# ```
