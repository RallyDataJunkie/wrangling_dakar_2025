# %% [markdown]
# # `waypoint` data
#
# The waypoint data appears to be defined at the stage level.

# %%
# Load in the required pandas package
import pandas as pd

# Generate the API URL pattern
dakar_api_template = "https://www.dakar.live.worldrallyraidchampionship.com/api/{path}"

# Define the year
YEAR = 2025
# Define the category
CATEGORY = "A"
# Define the stage
STAGE = 1

# Define the API path to the stage resource
# Use a Python f-string to instantiate variable values directly
waypoint_path = f"waypoint-{YEAR}-{CATEGORY}-{STAGE}"

# Define the URL
waypoint_url = dakar_api_template.format(path=waypoint_path)

# Preview the path and the URL
waypoint_path, waypoint_url
# Out:
# ('waypoint-2025-A-1',
#  'https://www.dakar.live.worldrallyraidchampionship.com/api/waypoint-2025-A-1')

# %%
_waypoint_df = pd.read_json(waypoint_url)
_waypoint_df
# Out:
#                _bind            _origin                               _id  \
# 0  waypoint-2025-A-1  waypoint-2025-A-1  4ae51c74af545e1d1735bdb5c3cd74ae
#
#   _key     _updatedAt                                        _parent  \
# 0  _id  1736183717267  stage-2025-A:4ae51c74af545e1d1735bdb5c3cd74ae
#
#                                            waypoints
# 0  [{'kilometerPoint': 38.83, 'checkpoint': 1, 'c...

# %% [markdown]
# The response type is a single result in a list. We can more conveniently parse the results out of this dataframe as follows:

# %%
stage_code = _waypoint_df.iloc[0]["_origin"]

waypoint_df = pd.json_normalize(_waypoint_df["waypoints"].explode())
waypoint_df["Year"] = YEAR
waypoint_df["Stage"] = STAGE
waypoint_df["Category"] = CATEGORY
waypoint_df["stage_code"] = stage_code

waypoint_df
# Out:
#     kilometerPoint  checkpoint   code  kilometerPointDisplay      id  hidden  \
# 0            38.83           1  01207                   39.0  125111   False
# 1            91.04           2  01216                   92.0  125112   False
# 2           121.18           3  01218                  122.0  125113   False
# 3           150.72           4  01220                  151.0  125114   False
# 4           181.18           5  01222                  182.0  125115   False
# 5           212.54           6  01224                  213.0  125116   False
# 6           243.32           7  01227                  244.0  125117   False
# 7           287.02           8  01230                  288.0  125119   False
# 8           329.07           9  01233                  330.0  125120   False
# 9           365.15          10  01237                  366.0  125121    True
# 10          412.95          11  012AS                  413.0  125122   False
# 11            0.00           0  012DS                    0.0  125110   False
# 12             NaN         999  01ASS                    NaN  125123   False
#
#     isCHR  isBRP  isASG  isLBL groups isFirstDss  Year  Stage Category  \
# 0    True  False  False  False   None        NaN  2025      1        A
# 1    True  False  False  False   None        NaN  2025      1        A
# 2    True  False  False  False   None        NaN  2025      1        A
# 3    True  False  False  False   None        NaN  2025      1        A
# 4    True  False  False  False   None        NaN  2025      1        A
# 5    True  False  False  False   None        NaN  2025      1        A
# 6    True  False  False  False   None        NaN  2025      1        A
# 7    True  False  False  False   None        NaN  2025      1        A
# 8    True  False  False  False   None        NaN  2025      1        A
# 9    True  False  False  False   None        NaN  2025      1        A
# 10  False  False  False   True   None        NaN  2025      1        A
# 11  False  False  False  False   None       True  2025      1        A
# 12  False  False  False   True   None        NaN  2025      1        A
#
#            stage_code
# 0   waypoint-2025-A-1
# 1   waypoint-2025-A-1
# 2   waypoint-2025-A-1
# 3   waypoint-2025-A-1
# 4   waypoint-2025-A-1
# 5   waypoint-2025-A-1
# 6   waypoint-2025-A-1
# 7   waypoint-2025-A-1
# 8   waypoint-2025-A-1
# 9   waypoint-2025-A-1
# 10  waypoint-2025-A-1
# 11  waypoint-2025-A-1
# 12  waypoint-2025-A-1

# %% [markdown]
# The waypoint data provides the distance into the stage of each waypoint, along with a wayuppint code and a waypoint ordering. The boolean flag information does not appear to be immediately useful.
