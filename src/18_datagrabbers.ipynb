# %% [markdown]
# # Data Sourcing One-Liners
#
# To simplify the retrieval of data from the API, I have bundled a set of simple functions for retrieving each type of data from the live data API.

# %%
from dakar_rallydj.getter import get_category

get_category()
# Out:
#    lastStage  position  mapDisplay reference                  updatedAt  \
# 1         12         3        True    2025-A  2025-01-06T12:11:14+01:00
# 0         12         8        True    2025-F  2025-01-06T12:12:00+01:00
# 2         12         7        True    2025-K  2025-01-06T12:11:52+01:00
# 3         12         0        True    2025-M  2025-01-05T20:25:31+01:00
#
#    refueling label  liveDisplay  promotionalDisplay  shortLabel  ...  \
# 1          1     A         True                True  cat.name.A  ...
# 0          0     F        False                True  cat.name.F  ...
# 2          0     K        False                True  cat.name.K  ...
# 3          1     M         True                True  cat.name.M  ...
#
#          _origin                               _id   _key     _updatedAt  \
# 1  category-2025  63b4f5da4591200d0a4cc239245eb03a  label  1736787045218
# 0  category-2025  0a0fb4dfc03bcb6b0e9c940b5a09ae05  label  1736787045218
# 2  category-2025  b0b0b0087d69431d87d04800e254c7c3  label  1736787045218
# 3  category-2025  e377e0f7b61dcf8217845dc4fac8cc5d  label  1736787045218
#
#                                       _parent  isPointCat  \
# 1  millesime:28a3b2a601a2028494b004bb95233853         NaN
# 0  millesime:28a3b2a601a2028494b004bb95233853         1.0
# 2  millesime:28a3b2a601a2028494b004bb95233853         1.0
# 3  millesime:28a3b2a601a2028494b004bb95233853         NaN
#
#                           ar                         en  \
# 1                     سيارات                        Car
# 0  DAKAR FUTURE MISSION 1000  DAKAR FUTURE MISSION 1000
# 2                    Classic                    Classic
# 3                      دراجة                       Bike
#
#                           es                         fr
# 1                      Coche                       Auto
# 0  DAKAR FUTURE MISSION 1000  DAKAR FUTURE MISSION 1000
# 2                    Classic                    Classic
# 3                       Moto                       Moto
#
# [4 rows x 22 columns]

# %%
from dakar_rallydj.getter import get_groups
get_groups().head()
# Out:
#    position  reference     shortLabel label  promotionalDisplay tinyLabel  \
# 8         0  2025-A-T1  cat.name.A_T1    T1                True       ULT
# 7         1  2025-A-T2  cat.name.A_T2    T2                True       STK
# 5         4  2025-A-T3  cat.name.A_T3    T3                True       CHG
# 6         5  2025-A-T4  cat.name.A_T4    T4                True       SSV
# 9         6  2025-A-T5  cat.name.A_T5    T5                True       TRK
#
#             _bind               _origin                               _id  \
# 8  allGroups-2025  categoryGroup-2025-A  b49155b3f5670d2a907aa01e319876b8
# 7  allGroups-2025  categoryGroup-2025-A  4dac064bf100bc806b91e7f2e7758297
# 5  allGroups-2025  categoryGroup-2025-A  15f329900afa29e3e6b099ae681ebe12
# 6  allGroups-2025  categoryGroup-2025-A  423ea731fdcba5cda62c8334985889b0
# 9  allGroups-2025  categoryGroup-2025-A  f1a437ac1135c9d9a5e33f5096f95259
#
#                                           _parent    color          ar  \
# 8  category-2025:63b4f5da4591200d0a4cc239245eb03a  #EBBC4E    Ultimate
# 7  category-2025:63b4f5da4591200d0a4cc239245eb03a  #C7C9C7       Stock
# 5  category-2025:63b4f5da4591200d0a4cc239245eb03a  #E04E39  Challenger
# 6  category-2025:63b4f5da4591200d0a4cc239245eb03a  #A7C6ED         SSV
# 9  category-2025:63b4f5da4591200d0a4cc239245eb03a  #2D2926       شاحنة
#
#            en          es          fr
# 8    Ultimate    Ultimate    Ultimate
# 7       Stock       Stock       Stock
# 5  Challenger  Challenger  Challenger
# 6         SSV         SSV         SSV
# 9       Truck      Camión      Camion

# %%
from dakar_rallydj.getter import get_clazz
get_clazz().head()
# Out:
#     refueling label       shortLabel    reference  position  \
# 10          0     +  cat.name.A_T1_+  2025-A-T1-+         4
# 13          0     1  cat.name.A_T1_1  2025-A-T1-1         0
# 11          0     2  cat.name.A_T1_2  2025-A-T1-2         1
# 12          0     3  cat.name.A_T1_3  2025-A-T1-3         2
# 9           0     U  cat.name.A_T1_U  2025-A-T1-U         3
#
#     promotionalDisplay            _bind                               _id  \
# 10                True  allClazz-2025-A  96c0869600e0013dbf5f86f60e5c4da4
# 13                True  allClazz-2025-A  f666973e89db183ecfefc75c3af8ffb1
# 11                True  allClazz-2025-A  f00d7ec8d2d96e9cf11aa515109376cf
# 12                True  allClazz-2025-A  f071b5dbfd586a4ba46100196a98a9c4
# 9                 True  allClazz-2025-A  1501ebcbaf3ad27e72aecfba7faa8037
#
#                                               _parent  \
# 10  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
# 13  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
# 11  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
# 12  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
# 9   categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...
#
#                                                $group color tinyLabel  \
# 10  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...   NaN       NaN
# 13  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...   NaN       NaN
# 11  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...   NaN       NaN
# 12  categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...   NaN       NaN
# 9   categoryGroup-2025-A:b49155b3f5670d2a907aa01e3...   NaN       NaN
#
#                                                ar  \
# 10          T1+: Prototype Cross-Country Cars 4x4
# 13          T1.1 Prototype Cross-Country Cars 4x4
# 11          T1.2 Prototype Cross-Country Cars 4x2
# 12                              T1.3 FIA: النتيجة
# 9   T1.U: "Ultimate" Prototype Cross-Country Cars
#
#                                                en  \
# 10          T1+: Prototype Cross-Country Cars 4x4
# 13          T1.1 Prototype Cross-Country Cars 4x4
# 11          T1.2 Prototype Cross-Country Cars 4x2
# 12                                    T1.3: SCORE
# 9   T1.U: "Ultimate" Prototype Cross-Country Cars
#
#                                                es  \
# 10          T1+: Prototype Cross-Country Cars 4x4
# 13          T1.1 Prototype Cross-Country Cars 4x4
# 11          T1.2 Prototype Cross-Country Cars 4x2
# 12                                   T1.3 : SCORE
# 9   T1.U: "Ultimate" Prototype Cross-Country Cars
#
#                                                    fr
# 10         T1+ : Voitures Tout-terrain Prototypes 4x4
# 13        T1.1 : Voitures Tout-terrain Prototypes 4x4
# 11        T1.2 : Voitures Tout-terrain Prototypes 4x2
# 12                                       T1.3 : SCORE
# 9   T1.U : Voitures Tout-Terrain Prototypes "Ultim...

# %%
from dakar_rallydj.getter import get_withdrawals

withdrawals_df, withdrawn_competitors_df, withdrawn_teams_df = get_withdrawals()

# %%
withdrawals_df.head()
# Out:
#     stage  bib reason       name
# 65      2  223      1    L. SANZ
# 66      2  223      1  M. GERINI
# 57      3  225      1   C. SAINZ
# 58      3  225      1    L. CRUZ
# 59      3  306      1  S. ALSAIF

# %%
withdrawn_competitors_df.head()
# Out:
#     bib              name   firstName       lastName role gender nationality  \
# 20  202      G. CHICHERIT    GUERLAIN      CHICHERIT    P      m         fra
# 21  202         A. WINOCQ        ALEX         WINOCQ    C      m         fra
# 22  206    G. DE VILLIERS      GINIEL    DE VILLIERS    P      m         zaf
# 23  206  D. VON ZITZEWITZ        DIRK  VON ZITZEWITZ    C      m         deu
# 38  208        B. VANAGAS  BENEDIKTAS        VANAGAS    P      m         ltu
#
#                                                profil  \
# 20  https://img.aso.fr/core_app/img-motorSports-da...
# 21  https://img.aso.fr/core_app/img-motorSports-da...
# 22  https://img.aso.fr/core_app/img-motorSports-da...
# 23  https://img.aso.fr/core_app/img-motorSports-da...
# 38  https://img.aso.fr/core_app/img-motorSports-da...
#
#                                             profil_sm  \
# 20  https://img.aso.fr/core_app/img-motorSports-da...
# 21  https://img.aso.fr/core_app/img-motorSports-da...
# 22  https://img.aso.fr/core_app/img-motorSports-da...
# 23  https://img.aso.fr/core_app/img-motorSports-da...
# 38  https://img.aso.fr/core_app/img-motorSports-da...
#
#                                                podium  \
# 20  https://img.aso.fr/core_app/img-motorSports-da...
# 21  https://img.aso.fr/core_app/img-motorSports-da...
# 22  https://img.aso.fr/core_app/img-motorSports-da...
# 23  https://img.aso.fr/core_app/img-motorSports-da...
# 38  https://img.aso.fr/core_app/img-motorSports-da...
#
#                                      aid
# 20  3d1b511c-fb5f-44a4-b93b-854666db93a6
# 21  cac1b0ad-da62-4ea1-ae4e-2c8426fabe90
# 22  d75b6d6e-1fc7-40f9-973e-7b051f19caef
# 23  1e9d8fe5-8cdb-4fcb-8036-7c9b2eff6492
# 38  77735d6e-4d5a-421d-8a32-0b3f21629f04

# %%
withdrawn_teams_df.head()
# Out:
#     team.bib          team.brand      team.model  \
# 9        202                MINI  JCW RALLY 3.0I
# 10       206              TOYOTA   HILUX IMT EVO
# 17       208              TOYOTA           HILUX
# 0        219               DACIA       SANDRIDER
# 11       220  HAN WEI MOTORSPORT         HWM T1+
#
#                           team.vehicle  \
# 9                 X-RAID MINI JCW TEAM
# 10                 TOYOTA GAZOO RACING
# 17  GURTAM TOYOTA GAZOO RACING BALTICS
# 0                 THE DACIA SANDRIDERS
# 11          212 HANWEI MOTORSPORT TEAM
#
#                                       team.vehicleImg  \
# 9   https://img.aso.fr/core_app/img-motorSports-da...
# 10  https://img.aso.fr/core_app/img-motorSports-da...
# 17  https://img.aso.fr/core_app/img-motorSports-da...
# 0   https://img.aso.fr/core_app/img-motorSports-da...
# 11  https://img.aso.fr/core_app/img-motorSports-da...
#
#                           team.clazz  team.w2rc
# 9   96c0869600e0013dbf5f86f60e5c4da4      False
# 10  96c0869600e0013dbf5f86f60e5c4da4      False
# 17  96c0869600e0013dbf5f86f60e5c4da4      False
# 0   96c0869600e0013dbf5f86f60e5c4da4       True
# 11  96c0869600e0013dbf5f86f60e5c4da4      False

# %%
from dakar_rallydj.getter import get_waypoints

get_waypoints().head()
# Out:
#      code      id  kilometerPointDisplay  checkpoint  kilometerPoint  hidden  \
# 11  012DS  125110                    0.0           0            0.00   False
# 0   01207  125111                   39.0           1           38.83   False
# 1   01216  125112                   92.0           2           91.04   False
# 2   01218  125113                  122.0           3          121.18   False
# 3   01220  125114                  151.0           4          150.72   False
#
#     isCHR  isBRP  isASG  isLBL groups  Year  stage Category         stage_code
# 11  False  False  False  False   None  2025      1        A  waypoint-2025-A-1
# 0    True  False  False  False   None  2025      1        A  waypoint-2025-A-1
# 1    True  False  False  False   None  2025      1        A  waypoint-2025-A-1
# 2    True  False  False  False   None  2025      1        A  waypoint-2025-A-1
# 3    True  False  False  False   None  2025      1        A  waypoint-2025-A-1

# %%
from dakar_rallydj.getter import get_stages

stages_df, sectors_df, stage_surfaces_df, section_surfaces_df, surfaces_df = get_stages()

# %%
sectors_df.head()
# Out:
#    powerStage   code     id  length                  startTime type  \
# 0       False  01100  23803      86  2025-01-04T04:30:00+00:00  LIA
# 1       False  01200  23804     413  2025-01-04T06:25:00+00:00  SPE
# 2       False  02100  23805      45  2025-01-05T03:25:00+00:00  LIA
# 3       False  02200  23806     967  2025-01-05T04:40:00+00:00  SPE
# 4       False  02300  23807      46  2025-01-05T13:00:00+00:00  LIA
#
#                  arrivalTime
# 0  2025-01-04T06:25:00+00:00
# 1  2025-01-04T10:35:00+00:00
# 2  2025-01-05T04:40:00+00:00
# 3  2025-01-05T13:00:00+00:00
# 4  2025-01-05T14:00:00+00:00

# %%
stage_surfaces_df.head()
# Out:
#     code  percentage    color          type
# 0  01200          18  #753a05    dirt track
# 1  01200          28  #1dc942  gravel track
# 2  01200          53  #efc07c          sand
# 3  01200          18  #753a05    dirt track
# 4  01200          28  #1dc942  gravel track

# %%
section_surfaces_df.head()
# Out:
#     code  section  start  finish    color          type
# 0  01200        1      0      27  #efc07c          sand
# 1  01200        2     27      32  #753a05    dirt track
# 2  01200        3     32      32  #1dc942  gravel track
# 3  01200        4     32      41  #efc07c          sand
# 4  01200        5     41      42  #753a05    dirt track

# %%
surfaces_df
# Out:
#            type       text_en          text_fr          text_es  text_ar
# 0    dirt track    Dirt Track      Piste terre  Pista de tierra  الحجارة
# 1  gravel track  Gravel Track  Piste empierrée           Tierra   التراب
# 2          sand          Sand            Sable            Arena   الرمال
# 3         dunes         Dunes            Dunes            Dunas  الكثبان
# 4  asphalt road  Asphalt Road          Goudron          Asfalto    الزفت
